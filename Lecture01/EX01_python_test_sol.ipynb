# %%
### 1/14 Test

# 1. 임의의 정수, 실수, 문자열, bool 값을 각각 변수 a, b, c, d에 담고, 각각의 데이터타입을 출력하시오.

# 2. 임의의 사람 이름을 입력받은 후, " <사람이름>님, 반갑습니다!!" 를 출력하도록 하시오
#   위의 코드를 세 가지 방식으로 구현하시오

# 3. 군집형 데이터  list, tuple, set, dictionary, string을 각각 생성해서
#   변수 l, t, s, d, st에 담으시오.

# 4. a = 100,    b = 5.3,    c = '5'
# 위의 a, b, c를 각각 정수, 실수, 문자열로 형변환하시오..단, 동일한 데이터타입의 경우 형변환은 필수가 아님

# 5. a = 5, b=10 위의 두 정수의 덧셈, 뺄셈, 곱셈, 나눗셈, 나머지, 몫, 승을 구하시오

# 6. a = 2, b=4 위의 두 정수의 크다, 작다, 크거나 같다, 작거나 같다, 같다,
# 같지 않다 의 비교연산 값을 출력하시오.

# 7. a = True, b=False, c= True 위의 세 변수를 이용해서 and연산과 or 연산의 결과를 출력하시오..

# %%
# 1. 임의의 정수, 실수, 문자열, bool 값을 각각 변수 a, b, c, d에 담고, 각각의 데이터타입을 출력하시오.
a = 11
b = 10.5
c = "python"
d = True

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
# 2. 임의의 사람 이름을 입력받은 후, " <사람이름>님, 반갑습니다!!" 를 출력하도록 하시오
#   위의 코드를 세 가지 방식으로 구현하시오

nam = input('이름을 입력하세요')
# print(nam)

# %%
#1
text = "%s님, 반갑습니다"%(nam)
print(text)
# Out:
# 이름을 입력하세요김훈
# 김훈님, 반갑습니다

# %%
#2
text = "{}님, 반갑습니다".format(nam)
print(text)
# Out:
# 김훈님, 반갑습니다

# %%
#3
text = f"{nam}님, 반갑습니다"
print(text)
# Out:
# 김훈님, 반갑습니다

# %%
# 3. 군집형 데이터  list, tuple, set, dictionary, string을 각각 생성해서
#   변수 l, t, s, d, st에 담으시오.

l = ['a','b','c','d']
t = ('a','b','c')
s = {'a','b','c'}
d = {'a':1, 'b':2, 'c':3}
st = "python"

# %%
# 4. a = 100,    b = 5.3,    c = '5'
# 위의 a, b, c를 각각 정수, 실수, 문자열로 형변환하시오..단, 동일한 데이터타입의 경우 형변환은 필수가 아님

a = 100;    b = 5.3;    c = '5'

d = int(a); e = int(b); f = int(c)

print(type(d), type(e), type(f))
# Out:
# <class 'int'> <class 'int'> <class 'int'>

# %%
d = float(a); e = float(b); f = float(c)

print(type(d), type(e), type(f))
# Out:
# <class 'float'> <class 'float'> <class 'float'>

# %%
d = str(a); e = str(b); f = str(c)

print(type(d), type(e), type(f))
# Out:
# <class 'str'> <class 'str'> <class 'str'>

# %%
# 5. a = 5, b=10 위의 두 정수의 덧셈, 뺄셈, 곱셈, 나눗셈, 나머지, 몫, 승을 구하시오

a = 5; b=10

c = a*b
d = a-b
e = a+b
f = a/b
g = a%b
h = a//b
i = a**b

print(c, d, e, f, g, h, i)
# Out:
# 50 -5 15 0.5 5 0 9765625

# %%
# 6. a = 2, b=4 위의 두 정수의 크다, 작다, 크거나 같다, 작거나 같다, 같다, 같지 않다 의
# 비교연산 값을 출력하시오. (비교연산 => True/False)

a = 2; b=4

print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
print(a == b)
print(a != b)
# Out:
# False
# True
# False
# True
# False
# True

# %%
# 7. a = True, b=False, c= True 위의 세 변수를 이용해서 and연산과 or 연산의 결과를 출력하시오..

a = True; b=False; c= True

print(a and b and c)
print(a or b or c)
# Out:
# False
# True

# %%
# 11/15

# %%
#  String

txt1 = 'A tale that was not right'

# 2. 'ale' 이 출력..
txt1[3:6]
# 3. 'A tale' 출력
txt1[:6]
# 4. 'not' 출력 – split()함수를 활용하시오
txt1.split()[4]
# 5. txt1을 소문자 전환
txt1.lower()
# 6. txt1을 대문자 전환
txt1.upper()
# 7. 'o'가 몇 개 존재하는가?
txt1.count('o')
# 8. 'o'가 몇 번 인덱스에 존재하는가?
txt1.find('o')
txt1.index('o')
# 9. txt1의 길이는 어떻게 되는가?
len(txt1)
# 11. 'tale'을  'story'로 바꾸세요..
txt1.replace('tale', 'story')
# 12. txt1 안에 'right'가 존재하는지 확인
'right' in txt1
# 13. space를 기준으로 나누어서 리스트에 담으시오.
txt1.split()
# ‘14. right’을 입력받은 값으로 바꾸어서 출력하는 코드를 만드시오
word = input('임의의 문자를 입력하세요')
txt1.replace('right', word)
# 15. ~ 20. 슬라이싱 하시오..
lang = 'python programming'
# 'tho'
lang[2:5]
# 'pro'
lang[7:10]
# 'ming'
lang[-4:]
# 'n p'
lang[5:8]
# 'ing'
lang[-3:]
# 'python
lang[:6]

# 21. 위의 (txt1, lang) 두 문자열을 연결하시오
txt1 + lang
# 22. 'hello'를 세 번 반복하시오
'hello' * 3
# 23. lang에 's'가 있는지 확인하시오
's' in lang
# 24. 이메일을 입력받은 후 id와 domain을 분리해서 출력하시오..
email = input('email을 입력하세요')
email_id = email.split('@')[0]
email_domain = email.split('@')[1]
print(email_id, email_domain)

# 25. 'hello <python>'에서 hello 대신 다른 단어가 들어갈 수 있도록 formatting을 만드시오
1. text = 'hello %s'%('java')
2. text = 'hello {}'.format('java')
3. name = 'java'
   text = f'hello {name}'

# List

solarsys = ['태양', '수성', '금성', '지구', '화성', '목성', '지구']
solarsys1 = ['토성', '천왕성', '해왕성']
planet = '지구'

# 1. solarsys 에서 ['수성', '금성', '지구'] 를 출력
solarsys[1:4]
# 2. solarsys에서 '지구'의 위치값 출력
solarsys.index('지구')
# 3. solarsys에서 '화성'을 '해왕성'으로 수정
solarsys[4] = '해왕성'
# 4. solarsys에 '토성'을 맨 끝에 첨가
solarsys.append('토성')
# 5. solarsys에서 '수성' 자리에 '명왕성'을 삽입
solarsys.insert(1, '명왕성')
# 6. solarsys에 맨 끝 요소를 제거하고 리턴
solarsys.pop()
# 7. solarsys에서 '금성'을 제거
solarsys.remove('금성')
# 8. solarsys에서 1번 인덱스에서 3번 인덱스까지 삭제
del solarsys[1:4]
# 9. solarsys에서 인덱스값 2번 요소를 삭제
solarsys.pop(2)
# 10.solarsys와 solarsys1을 합하시요.
solarsys + solarsys1
# 11. solarsys를 오름차순으로 정력하세요.
sorted(solarsys)
# 12. solarsys를 내림차순으로 정렬하세요.
sorted(solarsys, reverse=True)
# 13. solarsys의 원소의 순서를 역순으로 바꾸세요.
solarsys.reverse()
# 14. solarsys에 '만리장성'이 있는지 확인하세요.
'만리장서' in solarsys
# 15. solarsys를 3번 반복하세요.
solarsys * 3
# 16. solarsys의 길이를 리턴하세요.
len(solarsys)
# 17. solarsys에서 '지구'의 갯수를 출력하세요.
solarsys.count('지구')
# 18. solarsys의 모든 원소를 지워세요.
solarsys.clear()
# 19. solarsys 리스트를 삭제하세요.
del solarsys


# Tuple

myTuple = ("tuple", (1, 2, 3), [4, 5, 6])

#20. 'tuple'을 출력하시오
myTuple[0]
#21.  3을 출력하세요
myTuple[1][-1]
#22 4, 5를 출력하세요
myTuple[2][:2]
#23. 4를 출력하세요
myTuple[2][0]
#24. (1, 2, 3)을 출력하세요
myTuple[1]

my_tuple = (1, 2, 3, 3, 2, 1)
your_tuple = (4, 5, 6)

#26 my_tuple과 your_tuple을 연결하세요
my_tuple + your_tuple
#27 mytuple을 3번 반복하세요
my_tuple * 3
#28 mytuple에 3이 있는지 확인하세요
3 in mytuple
#29 mytuple에 5가 있는지 확인하세요
5 in mytuple
#30 mytuple에서 1의 갯수를 출력하세요
mytuple.count(1)
#31 mytuple에서 index 2번 자리의 값을 출력하세요
mytuple[2]

t_float = (120.09, 9.11, 2.8)
L_int = [1, 2, 3]

#32 t_float의 길이를 출력하세요
len(t_float)
#33 t_float의 최대값을 출력하세요
max(t_float)
#34 t_float의 최소값을 출력하세요
min(t_float)
#35 t_float의 합을 출력하세요.
sum(t_float)
#36 t_float의 평균을 출력하세요.
sum(t_float)/len(t_float)

import numpy as np
np.mean(t_float)
#37 t_float를 오름차순 정렬하세요
sorted(t_float)

# %%
email = input('email을 입력하세요')
# email_id = email.split('@')[0]
# email_domain = email.split('@')[1]
# print(email_id, email_domain)
# Out:
# email을 입력하세요fjkslf@fjlsf.com

# %%
email
# Out:
# 'fjkslf@fjlsf.com'

# %%
email.split('@')
# Out:
# ['fjkslf', 'fjlsf.com']

# %%
my_tuple = (5,2,3,3,2,5, 2)
num = int(input('찾고자 하는 원소를 입력하세요'))

while num in my_tuple:
    text = "인데스 값 : {} , 원소 값 : {}".format(my_tuple.index(num) , num)
    print(text)
    break
# Out:
# 찾고자 하는 원소를 입력하세요2
# 인데스 값 : 1 , 원소 값 : 2

# %%
### 23/11/16

### Set

# my_set이라는 빈 집합을 만들고 타입을 출력하세요..
my_set = set()
type(my_set)
# 'sky'와 'sea'를 요소로 하는 set을 만드세요
s = {'sky', 'sea'}
# 'earth' 요소를 추가하세요
s.add('earth')
# ('1', '2') 요소를 추가하세요
s.add('1')
s.add('2')
s.update({'1', '2'})
# 무작위로 요소 하나를 삭제하세요
s.pop()

s_planet = {'수성', '금성', '지구', '화성', '목성', '토성', '천왕성', '해왕성'}

# '금성' 을 삭제하세요
s_planet.remove('금성')
s_planet.discard('금성')
# 위와 다른 함수를 사용해서 '천왕성'을 삭제하세요
s_planet.remove('금성')
s_planet.discard('금성')
# 모든 항목을 지우세요
s_planet.clear()

A = {1, 2, 3, 4, 5, 6}
B = {1, 2, 3, 7, 8, 9}

# 합집합을 구하세요
A.union(B)
# 교집합을 구하세요
A.intersection(B)
# 차집합을 구하세요
A.difference(B)
# 대칭차집합을 구하세요
A.symmetric_difference(B)
# 부분집합
# {4, 5, 6}가 A의 부분집합인지 확인하세요
{4,5,6}.issubset(A)
# A가 {4, 5, 6}을 포함하닌지 확인하세요
A.issuperset({4,5,6})

s_float = {1.0, 3.0, 2.0, 10.0}

# s_float의 길이를 구하세요
len(s_float)
# s_float를 올림차순 정렬하세요
sorted(s_float)
# s_float에 2.0이 포함되는지 확인하세요
2.0 in s_float

# L = [1,2,3,4,3,2,3,4,5,3,3,2]
# 위의 리스트에서 중복값을 제거하시오..
set(L)


### Dictionary

solar1 = ['태양', '수성', '금성', '지구', '화성', '목성', '토성', '천왕성', '해왕성']
solar2 = ['Sun', 'Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
solardict = {}

# 아래와 같이 출력되도록 코딩하세요.
# for문을 사용하세요.
#
# {'태양': 'Sun', '수성': 'Mercury', '금성': 'Venus', '지구': 'Earth',
#  '화성': 'Mars', '목성': 'Jupiter', '토성': 'Saturn', '천왕성': 'Uranus', '해왕성': 'Neptune'}



names = {'Mary':10999, 'Sams':2111, 'Aimy':9778, 'Tom':20245,
'Michale':27115, 'Bob':5887, 'Kelly':7855}

# Aimy의 value를 10000으로 수정하세요
names['Aimy'] = 10000

names = {'Mary':10999, 'Sams':2111, 'Aimy':9778, 'Tom':20245,
'Michale':27115, 'Bob':5887, 'Kelly':7855}

# 'Sams'를 삭제하세요
names.pop('Sams')

# value 값들의 합을 구하세요
sum(names.values())
# value 값들의 최대값을 구하세요
max(names.values())
# key값들을 출력하세요
names.keys()
# value값들을 출력하세요
names.values()
# 모든 요소를 삭제하세요
names.clear()
# 이름을 입력받고, 이름의 수치값을 출력하도록 코딩하세요
nam = input('이름을 입력하세요')
names[nam]
names.get(nam)
names.setdefault(nam)
# names의 key와 value를 튜플 쌍으로 출력하시오
names.items()
# 이름을 입력받고, 이름이 없으면 값 10000으로 names에 추가하시오..
nam = input('이름을 입력하세요')
names.setdefault(nam, 10000)
# 이름을 입력받고, 이름이 없어도 오류가 발생하지 않도록 하시오..
nam = input('이름을 입력하세요')
names.get(nam)
# 'Jina'를 key로 7770을 value으로 하는 element를 추가하시오..
names['Jina'] = 7770

my_idol = {"name": "쯔위", "age": 18, "job": "singer"}

# age의 값을 출력하시오
my_idol['age']
# job의 값을 출력하시오
my_idol['job']
# name의 값을 '수지'로 수정하시오
my_idol['name'] = '수지'
# 'birth' 의 값을 '1994-07-07'로 추가하시오
my_idol['birth'] = '1994-07-07'
# 'manager'의 값을 'JYP'로 추가하시오
my_idol['manager'] = 'JYP'
my_idol.setdefault('manager', 'JYP')

my_idol = {'job': 'singer', 'age': 18, 'name': '수지', 'birth': '1994-10-10'}

# 'birth' 항목 가져오고 삭제하기
my_idol.pop('birth')
# 'age' 항목 삭제하기
my_idol.pop('age')
# 임의의 항목 가져오면서 삭제하기
my_idol.pop()
# 사전 비우기
my_idol.clear()
# my_idol 사전 삭제하기
del my_idol


# 형변환 함수

# s = "python is fun!!"
# 위의 문자열을 List, tuple, set으로 형변환하시오
list(s)
tuple(s)
set(s)

# L = [1,e,e,s,3,5,4]
# 위의 리스트를 set, string, tuple로 형변환하시오
set(L)
str(L)
tuple(L)

# %%
### 11/17
### IF문

# %%
# 1.  성적을 입력받은 후, 성적이 90점 이상이면 "합격입니다"를 출력하시오..
score = int(input("점수를 입력하세요"))

if score >= 90:
  print("합격입니다..")

# 2.  성적을 입력받은 후, 성적이 80점 이상이면 "합격입니다",
# 80점 미만이면 "불합격입니다"를 출력하시오..
score = int(input("점수를 입력하세요"))

if score >= 80:
  print("합격입니다..")
else:
  print('불합격입니다.')


# 3.  성적을 입력받은 후, 성적이 80점 이상이면 "합격입니다",
# 80점 미만이면 "수고하셨습니다"를 출력하고
# 70점 미만이면 "분발하세요"를 출력하고,
# 60점 미만이면 "다음 기회에 도전하세요"를 출력하시오
score = int(input("점수를 입력하세요"))

if score >= 80:
  print("합격입니다..")
elif score >= 70:
  print("수고하셨습니다")
elif score >= 60:
  print("분발하세요")
else:
  print('다음 기회에 도전하세요.')


# 4.  임의의 정수를 입력받은 후 짝수이면 "짝수입니다", 홀수이면 "홀수입니다"를 출력하시오..

num = int(input("임의의 정수를 입력하세요"))

if num%2 == 0:
  print("짝수입니다")
else:
  print("홀수입니다")

# 5.  체중과 키를 입력받은 후, bmi를 계산해서 30 이상이면 "비만입니다",
# 30 ~ 25 사이이면, "과체중입니다",
# 25 ~ 18 사이이면, "정상입니다"
# 18 미만이면 "저체중입니다"를 출력하시오
# bmi = weight/((height*0.01)**2)

weight = int(input("체중을 입력하세요(kg)"))
height = int(input("키를 입력하세요(cm)"))

bmi = weight/((height*0.01)**2)

if bmi >= 30:
  print('비만입니다')
elif bmi >= 25:
  print('과체중입니다')
elif bmi >= 18:
  print('정상입니다')
else:
  print('저체중입니다..')


# 6.  pass_word = "1234"
# pass_word를 입력받은 후, 맞으면 "환영합니다", 틀리면"비밀번호가 틀립니다"를 출력하시오...

pw = input('패스워드를 입력하세요')

if pw == '1234':
  print('환영합니다')
else:
  print('비밀번호가 틀립니다..')

# 7.  주민번호를 앞 7자리를 입력받은 후,
#  (주민번호 앞 6자리가 생년월일, 7자리가 1,3이면 남성, 2,4면 여성)
#  (age = 2023 - 출생년도)
#  40세 이상이면 중년, 20세 이상이면 청년. 20세 미만이면 청소년으로 간주하고
# "당신은 <남성/여성>이고, <중년/청년/청소년>입니다"를 출력하시오

res_num = input('주민번호 7자리를 입력하세요')

if res_num[-1] in ['1', '3']:
  gender = '남성'
else:
  gender = '여성'

if res_num[-1] in ['1', '2']:
  age = 2023 - int('19'+res_num[:2])
else:
  age = 2023 - int('20'+res_num[:2])

if age >= 40:
  generation = '중년'
elif age >=20:
  generation = '청년'
else:
  generation = '청소년'

# text= f"당신은 {gender}이고, {generation}입니다"
text= "당신은 {}이고, {}입니다".format(gender, generation)
print(text)

# 8. 아이디와 패스워드를 입력받은 후
# id = 'admin', password = '1234'
# 아이디만 틀리면 "아이디가 틀립니다"
# 패스워드만 틀리면 "패스워드가 틀립니다"
# 아이디와 패스워드 모두 틀리면 "아이디와 패스워드 모두 틀립니다",
# 아이디와 패스워드가 일치하면 "환영합니다"를 출력하시오.

id_name = input('id를 입력하세요')
pw = input('password를 입력하세요')

if id_name == 'admin':
  if pw == '1234':
    print('환영합니다')
  else:
    print('패스워드가 틀립니다')
else:
  if pw == '1234':
    print('아이디가 틀립니다')
  else:
    print('아이디와 패스워드가 모두 틀립니다.')

# 9. names = {'park':1500, 'kim':5478, 'minho':8754, 'lee':4589}
# key를 입력받은 후, key가 names에 있으면 value를 출력하고 없으면 key를 value 1000과 함께
# 추가하시오 단, setdefault를 사용하지 마시오..

names = {'park':1500, 'kim':5478, 'minho':8754, 'lee':4589}

nam = input('이름을 입력하세요')
if nam in names:
  print(names[nam])
else:
  names[nam] = 1000
  print(names)

# 10. 점수를 입력받은 후,
# 점수가 90이상이면 "A학점입니다"
# 점수가 80이상이면 "B학점입니다"
# 점수가 70이상이면 "C학점입니다"
# 점수가 60이상이면 "D학점입니다"
# 점수가 60미만이면 'F학점입니다'를 출혁하시오

score = int(input('점수를 입력하세요'))

if score >= 90:
  print('A학점입니다')
elif score >= 80:
  print("B학점입니다")
elif score >= 70:
  print("C학점입니다")
elif score >= 60:
  print("D학점입니다")
else:
  print('F학점입니다.')

# 11 임의의 정수 a와 b를 입력받은 후,
# a가 b보다 크면 "a가 b보다 큽니다"
# a가 b보다 작으면 "a가 b보다 작습니다"
# a와 b가 같으면 "a와 b가 같습니다"를 출력하시오..

a = int(input('임의의 정수를 입력하세요'))
b = int(input('임의의 정수를 입력하세요'))

if a>b:
  print('a가 b보다 큽니다')
elif a<b:
  print('a가 b보다 작습니다')
else:
  print('a와 b가 같습니다')


# 12 가위, 바위, 보 게임을 if문으로 구현하시오

mine = input('가위, 바위, 보를 내세요')
yours = input('가위, 바위, 보를 내세요')

if mine == yours:
  print('비겼습니다')
elif mine == '가위':
  if yours =='바위':
    print("당신이 이겼습니다")
  else:
    print("내가 이겼습니다")
elif mine == '보':
  if yours =='가위':
    print("당신이 이겼습니다")
  else:
    print("내가 이겼습니다")
else:
  if yours =='보':
    print("당신이 이겼습니다")
  else:
    print("내가 이겼습니다")

# %%
# 23/11/20  For/While

# %%
# 1. 아래 리스트의 원소를 하나씩 출력..
L = ['a', 'b','c','d']

for i in L:
  print(i, end=' ')

# 2. range()함수를 이용해서 indexing을 통해서 위의 리스트 값을 하나씩 출력
for i in range(len(L)):
  print(L[i])

# 3~4. names = ['철수', '영희', '바둑이', '귀도'] 리스트를 아래와 같이 출력하시오
# 1번 : 철수
# 2번 : 영희
# ...
# 4번 : 귀도

# 방법 1 : range()함수를 이용하시오
for i in range(len(names)):
  print("{}번 : {}".format(i+1, names[i]))

# 방법 2 : enumerate() 함수를 이용하시오
for i, n in enumerate(names):
  print("{}번 : {}".format(i+1, n))

# 5. 'python'을 반복문을 이용해서 'NOHTYP'으로 출력되도록 하시오

s = ''
for c in 'python':
  s = c.upper() + s
print(s)

text = 'python'
for i in range(len(text)-1, -1, -1):
  print(text[i].upper(), end='')

# 6. {'a':1,'b':2,'c':3} 딕셔너리의 key와 value를 바꿔서 새로운 dict를 만드시오

d = {'a':1,'b':2,'c':3}
d1 = {}
for t in d.items():
  key = t[0]
  val = t[1]
  d1[val] = key
d1

# x = ['a','b','c','d']
# y = ['가', '나', '다']
# 7. 두 리스트의 모든 원소의 조합을 리스트에 담으시오 => ('a', '가'), ('a', '나') ... ('d', '나'), ('d', '다')
L = []
for i in x:
  for j in y:
    L.append((i, j))


# 8. 위의 코드를 list comprehension으로 구현하시오..

[(i, j) for i in x for j in y]

# 9. s = "pythonprogramming"
# for문을 통해서 s를 모음만 대문자로 수정하시오.. 모듬 : 'aeiou'
for c in s:
  if c in 'aeiou':
    c = c.upper()
  print(c, end='')

# 10. s = "python is fun and easy" 아래와 같이 단어 단위로 나누어서 길이와 함께 출력하시오.
# python, 6
# is, 2
# fun, 3
# and, 3
# easy, 4

for w in s.split():
  print(w, len(w))

# 11. 0부터 10까지 정수에서 짝수만 리스트에 담으시오...
L = []
for i in range(11):
  if i%2==0:
    L.append(i)

# 12. 위의 코드를 list comprehension으로 구현하시오
[i for i in range(11) if i%2==0]
[i for i in range(0,11,2)]

# 13. 0부터 10까지 정수의 합을 구하시오...
suma = 0
for i in range(11):
  suma += i
suma

# 14. 0부터 10까지 3의 배수의 합을 구하시오...
suma =0
for i in range(11):
  if i%3==0:
    suma+=i
suma

# alpha = ['a','b','c','d']
# han = ['가', '나','다','라']
# {'a':'가', 'b':'나', 'c':'다', 'd':'라'}
# 15. for문을 이용해서 위의 dict를 만드시오..
d = {}
for i in range(alpha):
  d[alpha[i]] = han[i]
d

# 16. words = ['mountains', 'sea', 'sky', 'river', 'cloud', 'sea', 'sky', 'sea','mountains']
# 위의 단어 중에서 중복값을 제거하고 unique한 단어로만 리스트를 구성하시오.(중복단어 제거) 단, set()은 사용하지 마시오...
L = []
for w in words:
  if w not in L:
    L.append(w)

# 17. 아래의 모양을 반복문으로 출력하시오
#     *
#    **
#   ***
#  ****
# *****

for i in range(1,6):
  print(' '*(5-i), '*'*i)

# 18. 위의 단어에서 단어의 길이가 4 이상인 단어만 중복없이 저장(출력)하시오..
for w in words:
  if len(w) >= 4:
    print(w)

# 19. 0부터 10까지 정수의 합을 구하시오... while문으로 구현하시오
count = 0
suma = 0
while count <= 10:
  suma += count
  count += 1

# 20. 위의 while 반복문에서 5 이하의 정수만 출력하도록 하시오. 단, break를 사용하시오
count = 0
while count <= 10:
  if count > 5:
    break
  print(count)
  count += 1

# 21. 위의 while 반복문에서 짝수만 출력하도록 하시오. 단, continue를 사용하시오
count = -1
while count <= 10:
  count += 1
  if count%2 != 0:
    continue
  print(count)

# 22. 0~10까지 정수를 반복하는 반복문에서 3,4,5,6만 출력되도록 하시오, while문과 break, continue를 사용하시오..
count = -1
while count <= 10:
  count += 1
  if count < 3:
    continue
  if count > 7:
    break
  print(count)

# 23. 점수를 5번 입력을 받은 후, 점수의 평균을 출력하시오.
# 단, while문을 사용하시오...

suma = 0
count = 0
while count < 5:
  score = int(input("점수를 입력하세요"))
  suma += score
  count += 1

total_sum = suma/count
total_sum

# %%
### 2023-11-21

# File

# web에서 text를 복사해서 web_text.txt 파일에 쓰고,
# 4가지 버젼으로 전체 내용을 출력하시오..

text = """
hello python
python is fun!!
python is easy!!"""

f = open('web_text.txt', 'w')
f.write(text)
f.close()

f = open('web_text.txt', 'r')
contents = f.read()
f.close()
print(contents)

f = open('web_text.txt', 'r')
contents = f.readlines()
f.close()

for line in contents:
  print(line)

f = open('web_text.txt', 'r')
for line in f:
  print(line)

f = open('web_text.txt', 'r')
text = f.readline()

while text:
  print(text)
  text = f.readline()

# stockcode.txt파일의 내용을 dictionary로 저장하시오
# 단, key는 '종목명'으로 하시오...

# 214570 삼성전자
# 002487 현대차
# 578450 LG전자
# ...

f = open('stockcode.txt', 'r')
d = {}

for line in f:
  d[line.split()[0]] = line.split()[1]

# "bird.jpg" 이미지 파일을 복사해서 동일한 이미지인
#  "bird_copy.jpg" 파일을 만드시오.

f = open('bird.jpg', 'rb')
g = open('bird_copy.jpg', 'wb')

content = f.read()
g.write(content)

f.close()
g.close()

# 간편 메모장을 만드시오

num = input('쓰려면 1을 입력, 읽으려면 0을 입력')

if num =='1':
  text = input('입력할 내용을 입력하세요')
  f = open('memo.txt', 'a')
  f.write(text)
  f.close()

else:
  f = open('memo.txt', 'r')
  content = f.read()
  print(content)
  f.close()

# Function

x = ['a', 'b', 'c']
y = [1, 2, 3]
# zip 함수를 이용해서 위의 두 sequence의 동일 인덱스 원소간의 조합을 출력하시오..

for i in zip(x, y):
  print(i)

# %%
### 2023-11-22 Function

# %%
# 1. 1부터 10까지 정수의 합을 리턴하는 함수..
def test_sum():
  return sum([i for i in range(11)])
# 2. 임의의 정수를 a, b를 입력받은 후 a부터 b까지의 합을 리턴하는 함수..
def test_sum():
  return sum([i for i in range(a, b+1)])
# 3. 절대값을 리턴하는 함수를 생성하고 실행하시오.. 단, abs()함수를 사용하지 마시오...
def absf(n):
  if n < 0:
    return n*(-1)
  else:
    return n
# 4. 매개변수를 임의의 정수 a, b 두 개를 입력받은 후,
# 사칙연산 결과값을 리턴하는 함수를 만들고 실행하시오...
# (덧셈, 곱셈, 나눗셈, 뺄셈)
def four_cal(a,b):
  suma = a+b
  minu = a-b
  divv = a/b
  mult = a*b
  return suma, minu, divv, mult
# 5. 키와 몸무게를 입력으로 받은 후 bmi지수값을 리턴하는 함수를 현하시오
# bmi = weight/((height*0.01)**2)
def cal_bmi(w, h):
  bmi = w/((h*0.01)**2)
  return bmi
# 6. 함수를 실행하면 => "<>님!1, 오늘은 <>년도 <>월 <>일입니다.."를 출력하는 함수
import datetime
y, m, d = datetime.datetime.now().strftime('%Y-%m-%d').split('-')

def to_date(name):
  y, m, d = datetime.datetime.now().strftime('%Y-%m-%d').split('-')
  text = "{}님!1, 오늘은 {}년도 {}월 {}일입니다..".format(name, y, m, d)
  return text
# 7. 오늘의 날씨를 출력하는 함수 today_weather()를 구현하시오
# url = 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EB%82%A0%EC%94%A8'
# path = '#main_pack > section.sc_new.cs_weather_new._cs_weather > div._tab_flicking > div.content_wrap > div.open > div:nth-child(1) > div > div.weather_info > div > div._today > div.weather_graphic > div.temperature_text > strong'
# => "오늘의 기온은 <>도입니다"

def today_weather():
  url = 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EB%82%A0%EC%94%A8'
  path = '#main_pack > section.sc_new.cs_weather_new._cs_weather > div._tab_flicking > div.content_wrap > div.open > div:nth-child(1) > div > div.weather_info > div > div._today > div.weather_graphic > div.temperature_text > strong'

  res = requests.get(url)
  soup = BeautifulSoup(res.text, 'html.parser')
  tag = soup.select(path)
  result = tag[0].text

  return result

# 8. text_file, '수정할 단어', '새로운 단어'를 입력받은 후 text_file에서 수정할 단어를 새로운 단어로 하는 함수
# 'stockcode_copy.txt'에서 '삼성전자'를 => 'samsung electronics'로 수정...
def word_chg(file, old_word, new_word):
  f = open(file, 'r')
  text = f.read()
  f.close()
  g = open(file, 'w')
  g.write(text.replace(old_word, new_word))
  g.close()

# 9. "<고객님|이름>!! 감사합니다.."를 출력하는 함수
# 고객의 이름이 입력되지 않으면 "<고객님>!! 감사합니다..",
# 고객의 이름이 입력되면 "<이름>!! 감사합니다..",를 출력하는 함수를 구현하시오

def greetings(name = '고객님'):
  text = "{}!! 감사합니다..".format(name)
  return text

# 10. 일반매개변수와 가변매개변수를 가지고 모든 인수의 입력값의 합을 출력하는 함수를 구현하시오

def sumf(a, *b):
  return a + sum(b)

# 11. 일반매개변수와 가변매개변수, 키워매개변수를 가진 함수에서 모든 인수값의 평균을 리턴하는 함수를 구현하시오..
def sumf(a, *b, **c):
  return (a + sum(b) + sum(c.values()))/(1+len(b)+len(c))

# 12. 일반매개변수, 가변매개변수, 키워드매개변수를 가지고 입력된 value의 합을 리턴하는 익명함수(lambda)를 만드시오
f = lambda a, *b, **c : (a + sum(b) + sum(c.values()))
