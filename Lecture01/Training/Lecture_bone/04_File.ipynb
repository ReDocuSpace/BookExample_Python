# %%
path= '/content/drive/MyDrive/국제컴퓨터_빅데이터/python/data_files/'

# %%
### file

# 1. file 열기 => f = open('filename', 'r/w/a'), with open('filename', 'r/w/a') as f:

# 2. file 읽기/쓰기(이어쓰기)

# 2-1 읽기
# f.read()
# f.readline()
# f.readlines()
# for line in f:

# 2-2 쓰기
# f.write()

# 3. file 닫기
# f.close()

# %%
f = open(path + 'test_file.txt', 'r')
text = f.read()
f.close()
print(text)

# %%
f = open(path + 'test_file.txt', 'r')
text = f.readline()
f.close()
print(text)

# %%
f = open(path + 'test_file.txt', 'r')
text = f.readlines()
f.close()
print(text)

# %%
f = open(path + 'test_file.txt', 'r')
for line in f:
  print(line)
f.close()

# %%
# pwd - 나의 위치 확인
# / - 하위 폴더
# .. - 상위 폴더
# . - 현재 나의 위치

# window => \
# python => /

# "\, \\, /"
# 폴더명 : 한글, 특수기호 지양..
# "os.path.join"
# 너무 깊게 폴더 구성 지양...

# %%
f = open(path + 'test_file.txt', 'w')
f.write('python file open close...')
f.close()

# %%
f = open(path + 'test_file.txt', 'r')
text = f.read()
f.close()
print(text)

# %%
f = open(path + 'test_file.txt', 'a')
f.write('hello python')
f.close()

# %%
f = open(path + 'test_file.txt', 'r')
text = f.read()
f.close()
print(text)

# %%
f = open(path + 'score.txt', 'w')
f.write('1 84\n')
f.write('2 75\n')
f.write('3 88\n')
f.write('4 98\n')
f.close()

# %%
import os
os.listdir(path)

# %%
with open(path+'score.txt', 'r') as f:
  text = f.read()

print(text)

# %%
# 1번 : 84
# 2번 : 75
# 3번 : 88
# 4번 : 98

with open(path+'score.txt', 'r') as f:
  for line in f:
    # print(line)
    num = line.split()[0]
    score = line.split()[1]

    print("{}번 : {}".format(num, score))

# %%
# web에서 text를 복사해서 web_text.txt 파일에 쓰고,
# 4가지 버젼으로 전체 내용을 출력하시오..

text = """
나 보기가 역겨워 가실 때에는
말없이 고이 보내 드리오리다
나 보기가 역겨워 가실 때에는
죽어도 아니 눈물 흘리오리다
날 떠나 행복한지 이젠 그대 아닌지
그댈 바라보며 살아온 내가
그녀 뒤에 가렸는지
사랑 그 아픔이 너무커 숨을 쉴 수가 없어
그대 행복하길 빌어줄께요
내 영혼으로 빌어줄께요
나 보기가 역겨워 가실 때에는
말없이 고이 보내 드리오리다
영변에 약산 진달래꽃
아름따다 가실 길에 뿌리오리다
가시는 걸음 놓인 그 꽃을
사뿐히 즈려 밟고 가시옵소서
나 보기가 역겨워 가실 때에는
죽어도 아니 눈물 흘리오리다 """

f = open(path+'my_poem.txt', 'w')
f.write(text)
f.close()

# %%
# 1. read()
f = open(path+'my_poem.txt', 'r')
contents = f.read()
f.close()

print(contents)

# %%
# 2. readlines()

f = open(path + "my_poem.txt", 'r')
contents = f.readlines()
f.close()

for line in contents:
  print(line)

# %%
# 3. readline()

f = open(path + "my_poem.txt", "r")

line = f.readline()

while line:
  print(line)
  line = f.readline()

# %%
# 4. for

f = open(path + "my_poem.txt", 'r')

for line in f:
  print(line)

# %%
# stockcode.txt 파일의 내용을 출력하시오..
# 'utf-8', 'euckr', 'cp949

with open(path + 'stockcode.txt', 'r', encoding='euckr') as f:
  for line in f:
    print(line)

# %%
# "삼성전자"의 종목코드를 출력하시오..

with open(path + 'stockcode.txt', 'r', encoding='euckr') as f:
  for line in f:
    code = line.split()[0]
    name = line.split()[1]

    if name == '삼성전자':
      print(code)
      break
# Out:
# 005930

# %%
f = open(path + "stockcode.txt", 'r', encoding='euckr')

for line in f:
  code = line.split()[0]
  name = line.split()[1]

  if code == '005930':
    print(code, name)
    break
# Out:
# 005930 삼성전자

# %%
# 종목명을 받아서 종목code을 출력하는 python code를 구현하시오..

# %%
st_name = input('종목명을 입력하세요')

with open(path + 'stockcode.txt', 'r', encoding='euckr') as f:
  for line in f:
    code = line.split()[0]
    name = line.split()[1]

    if name == st_name:
      print(code)
      break

# %%
# stockcode.txt파일의 내용을 dictionary로 저장하시오
# 단, key는 '종목명'으로 하시오...

st_dic = {}

with open(path + 'stockcode.txt', 'r', encoding='euckr') as f:
  for line in f:
    code = line.split()[0]
    name = line.split()[1]

    st_dic[name] = code

# %%
st_dic

# %%
st_dic['삼성전자']

# %%
st_dic['LG전자']

# %%
# 'stockcode.txt'의 파일내용을 동일하게 가진 'stockcode_copy.txt'를 만드시오

# %%
f = open(path + "stockcode.txt", 'r', encoding='euckr')
g = open(path + "stockcode_copy.txt", 'w')

contents = f.read()
g.write(contents)

f.close()
g.close()

# %%
os.listdir(path)

# %%
from IPython.display import Image
Image(path + 'bird.jpg')

# %%
f = open(path + 'bird.jpg', 'rb')
g = open(path + 'bird_copy.jpg', 'wb')
contents = f.read()
g.write(contents)

f.close()
g.close()

# %%
from IPython.display import Image
Image(path + 'bird_copy.jpg')

# %%
# 메모장...

use = input('메모장를 쓰려면 1, 메모장를 읽으려면 0을 입력하세요..')

if use == '1':
  msg = input("기록할 내용을 입력하세요")
  f = open("memo.txt" , 'a')
  f.write(msg + '\n')
  f.close()
  print("입력하신 내용을 메모장에 기록했습니다..")

else:
  f = open("memo.txt", 'r')
  text = f.read()
  print(text)
  f.close()
