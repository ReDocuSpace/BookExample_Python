# %%
#부동산에서 내가 원하는 매물정보를 출력하고싶다.

import requests
from bs4 import BeautifulSoup
url = 'https://new.land.naver.com/complexes?ms=37.5301685,127.1233955,16&a=APT:PRE&e=RETAIL'

headers = {
    'Referer' : 'https://new.land.naver.com/complexes?ms=37.530126,127.123771,15&a=APT:PRE&e=RETAIL',
    'User_Agent' : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36"
}

res = requests.get(url, headers = headers)
res.text
soup = BeautifulSoup(res.text)
print(res.text)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="ko">
# <head>
# <meta http-equiv="Content-Type" content="text/html;charset=utf-8">
#     <link rel="canonical" href="http://land.naver.com">
#     <meta property="og:site_name" content="land" />
#     <meta property="og:title" content="네이버페이 부동산" />
#     <meta property="og:type" content="article" />
#     <meta property="og:description" content="내 집 마련의 시작, 네이버페이 부동산" />
#     <meta name="description" content="내 집 마련의 시작, 네이버페이 부동산">
#     <meta property="og:image" content="https://ssl.pstatic.net/static/m/land/img/og_land.png"/>
#     <meta property="og:article:author" content="네이버페이 부동산" />
#     <meta property="og:url" content="http://land.naver.com/index.naver" />
#     <meta property="og:article:author:url" content="http://land.naver.com/" />
#     <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>
#
#
#
#     <style type="text/css">
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import requests
from bs4 import BeautifulSoup

url = 'https://finance.naver.com/item/sise.naver?code=005930'

res = requests.get(url)

soup = BeautifulSoup(res.text, 'html.parser')

# 테이블을 가져온다.
path = 'body table'
len(soup.select(path))

tables = soup.select(path)

# table tag를 모두 가져옴 - tabel tag : 표
len(pd.read_html(res.text))  

# table을 dataframe으로 바로 불러온다.
tables = pd.read_html(res.text) 

# 1. webdriver를 main_url로 이동, page_source
# iframe 불러오기
main_url = 'https://finance.naver.com'
iframe_url = '/item/sise_day.naver?code=005930'

url = main_url + iframe_url
# Out:
# <table class="no_info" summary="주요 시세(전일종가, 시고저가, 거래량, 거래대금)을 제공합니다.">
# <caption>주요 시세</caption>
# <colgroup><col/><col width="214"/><col width="157"/></colgroup>
# <tr>
# <td class="first">
# <span class="sptxt sp_txt2">전일</span>
# <em>
# <span class="blind">72,000</span>
# <span class="no7">7</span><span class="no2">2</span><span class="shim">,</span><span class="no0">0</span><span class="no0">0</span><span class="no0">0</span>
# </em>
# </td>
# <td>
# <span class="sptxt sp_txt4">고가</span>
# <em class="no_up">
# <span class="blind">72,900</span><span class="no7">7</span><span class="no2">2</span><span class="shim">,</span><span class="no9">9</span><span class="no0">0</span><span class="no0">0</span>
# </em>
# <span class="sptxt sp_txt6">(상한가</span>
# <em class="no_cha">
# <span class="blind">93,600</span><span class="no9">9</span><span class="no3">3</span><span class="shim">,</span><span class="no6">6</span><span class="no0">0</span><span class="no0">0</span>
# </em>
# ...

# %%
url = 'https://www.melon.com/chart/week/index.htm?classCd=GN0000&moved=Y&startDay=20230130&endDay=20230205'
# url = 'Request URL: https://www.melon.com/chart/week/index.htm'

headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36',
    'Referer':'https://www.melon.com/chart/day/index.htm',
    'Host':'www.melon.com'
}

params = {
'classCd': 'GN0000',
'moved': 'Y',
'startDay': '20230130',
'endDay': '20230205'
}

res = requests.get(url)

# %%
# krx
import requests

url = 'http://data.krx.co.kr/comm/bldAttendant/getJsonData.cmd'

headers = {
'Accept': 'application/json, text/javascript, */*; q=0.01',
'Accept-Encoding': 'gzip, deflate',
'Accept-Language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
'Connection': 'keep-alive',
'Content-Length': '120',
'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
'Cookie': '__smVisitorID=-qOIb6444VH; JSESSIONID=pHAaRP113ysufAKU3rZdQx6iudOpBzVNcGHErAdgTp88hjURba6b49Y2oxuMGa7N.bWRjX2RvbWFpbi9tZGNvd2FwMS1tZGNhcHAxMQ==',
'Host': 'data.krx.co.kr',
'Origin': 'http://data.krx.co.kr',
'Referer': 'http://data.krx.co.kr/contents/MDC/MDI/mdiLoader/index.cmd?menuId=MDC0201',
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36',
'X-Requested-With': 'XMLHttpRequest'
}

data = {
    'bld': 'dbms/MDC/STAT/standard/MDCSTAT00101',
'locale': 'ko_KR',
'idxIndMidclssCd': '01',
'trdDd': '20230222',
'share': '2',
'money': '3',
'csvxls_isNo': False
}

res = requests.post(url, headers=headers, data=data)

df = pd.DataFrame(eval(res.text)['output'])
df
# Out:
#                IDX_NM CLSPRC_IDX FLUC_TP_CD CMPPREVDD_IDX FLUC_RT OPNPRC_IDX  \
# 0             KRX 300   1,438.83          2        -26.34   -1.80   1,448.13
# 1             KTOP 30   8,517.70          2       -147.23   -1.70   8,562.92
# 2             KRX 100   4,941.54          2        -92.85   -1.84   4,974.86
# 3             KRX 자동차   1,768.36          2        -33.20   -1.84   1,783.09
# 4             KRX 반도체   2,633.56          2        -74.99   -2.77   2,660.93
# 5            KRX 헬스케어   2,570.48          2        -64.67   -2.45   2,604.78
# 6              KRX 은행     642.45          2        -12.55   -1.92     650.51
# 7           KRX 에너지화학   3,167.71          2        -82.61   -2.54   3,202.62
# 8              KRX 철강   1,801.83          2        -31.92   -1.74   1,809.22
# 9            KRX 방송통신     702.43          2        -14.14   -1.97     706.01
# 10             KRX 건설     604.84          2        -13.77   -2.23     608.37
# ...
