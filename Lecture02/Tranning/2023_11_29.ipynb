# %%
import requests
from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

url = "https://korean.visitkorea.or.kr"

res = requests.get(url)

soup = BeautifulSoup(res.text, 'html.parser')

# path 찾는 방법
# 사이트 > 우상단 단추 > 도구더보기 > 개발자도구 > 좌상단 : select an element
# > 원하는 콘텐츠 클릭 > script highlight > 우클릭 > copy select
path = '#search_result > ul > li > div.cont > div.tit > a'

soup.select(path) # requests가 안됨

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

url = "https://korean.visitkorea.or.kr"

# 실시간 사람이 하는 듯한 작업
driver = webdriver.Chrome()
driver.get(url)

sk = input('검색할 키워드를 입력하세요 : ')

### 사용자의 동작을 정의하는 내용
# 페이지 로딩이후 element를 찾기 때문에
# time.sleep(1)을 통해 로딩이 완료되기 까지 대기 시간을 정의할 수 있다.
time.sleep(1)

# id를 통해 잡기
elem = driver.find_element('id','inp_search_mo')
elem.send_keys(sk)

# 버튼을 찾아서 클릭한다.
btn_elem = driver.find_element(By.CSS_SELECTOR, '#placeHolder > a')
btn_elem.click()

# 버튼을 찾아서 클릭한다
elem = driver.find_element(By.CSS_SELECTOR, '#s_attraction > div.more_view > a')
elem.click()

# html 코드 가져오기
html = driver.page_source

soup = BeautifulSoup(html, 'html.parser')

path = '#search_result > ul > li > div.cont > div.tit > a'

for item in soup.select(path):
    print(item.text)

# requests(url) - 프로그램적으로 서버에 요청 (브라우저를 사용하지 않음)
# selenium : page_source - 브라우저를 통해서 요청

# parsing은 BeautifulSoup으로 하는 과정은 동일

# %%
# url = 'https://korean.visitkorea.or.kr' 에서 
# 검색결과 기사페이지의 기사 summary를 가져오기

from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

url = "https://korean.visitkorea.or.kr"

driver = webdriver.Chrome()
driver.get(url)

select = "강릉"

# 대기 시간
time.sleep(1)

################################
# id를 통해 잡기
elem = driver.find_element(By.ID,'inp_search_mo')
elem.send_keys(sk)

# 버튼을 찾아서 클릭한다.
btn_elem = driver.find_element(By.CSS_SELECTOR, '#placeHolder > a')
btn_elem.click()

################################
# 대기 시간
time.sleep(1)

# 버튼을 찾아서 클릭한다
elem = driver.find_element(By.CSS_SELECTOR, '#s_recommend > div.more_view > a')
elem.click()


################################
html = driver.page_source

soup = BeautifulSoup(html, 'html.parser')

path = '#search_result > ul > li > div.cont > div.tit > a'

#for item in soup.select(path):
#    print(item.text)

# %%
li_path = '#search_result > ul > li'
li_tag = soup.select(li_path)

for item in li_tag:
    try:
        title = item.select('div.cont > div.tit > a')[0].text
        try:
            region = item.select('div.cont > span')[0].text
        except:
            region = ''
        tags = item.select('div.cont > div.tag > span')[0].text
    except:
        pass
    
    print(title, region, tags)

# %%
driver.find_element(By.LINK_TEXT, '2').click()

# %%
# url = 'https://korean.visitkorea.or.kr' 에서 
# 검색결과 기사페이지의 기사 summary를 가져오기

from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

url = "https://korean.visitkorea.or.kr"

# 크롬드라이버 열기
driver = webdriver.Chrome()
# url 열기
driver.get(url)
# 윈도우사이즈 세팅하기
driver.set_window_size(1000,1500)

select = "강릉"

# 대기 시간
time.sleep(1)

################################
# id를 통해 입력창 잡기
elem = driver.find_element(By.ID,'inp_search_mo')
elem.send_keys(sk)

# 버튼을 찾아서 클릭한다.
btn_elem = driver.find_element(By.CSS_SELECTOR, '#placeHolder > a')
btn_elem.click() # 검사결과페이지로 이동한다

# 대기 시간
time.sleep(1)

# 더보기 버튼을 찾아서 클릭한다
elem = driver.find_element(By.CSS_SELECTOR, '#s_recommend > div.more_view > a')
elem.click()


################################
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

li_path = '#search_result > ul > li'
li_tag = soup.select(li_path)

count = 1
while count <= 10:
    # 분석된 데이터 출력하기
    for item in li_tag:
        try:
            title = item.select('div.cont > div.tit > a')[0].text
            try:
                region = item.select('div.cont > span')[0].text
            except:
                region = ''
            
            tags = [t.text for t in item.select('div.cont > div.tag > span')]
        except:
            pass
    
        print(title, region, tags)
    
    count += 1
    # paging => 페이지 번호를 클릭한다..
    if count == 6:  # 6 => 다음을 클릭
        page= '다음'
    elif count == 11:  # 11 => 반복을 마침
        break
    else:
        page = count
    
    print(page)
    
    driver.find_element(By.LINK_TEXT, f"{page}").click()
    
    time.sleep(1.0)
# Out:
# 2
# 3
# 4
# 5
# 다음
# 7
# 8
# 9
# 10

# %%
from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

url = "https://korean.visitkorea.or.kr"

# 크롬드라이버 열기
driver = webdriver.Chrome()
# url 열기
driver.get(url)
# 윈도우사이즈 세팅하기
driver.set_window_size(1000,1500)

select = "강릉"

# 대기 시간
time.sleep(1)

################################
# id를 통해 입력창 잡기
elem = driver.find_element(By.ID,'inp_search_mo')
elem.click()

elem = driver.find_element(By.ID,'inp_search_index')
elem.send_keys(sk)

# 버튼을 찾아서 클릭한다.
btn_elem = driver.find_element(By.CSS_SELECTOR, 'body > div.search_index > div > div > div > div.form > button:nth-child(3)')
btn_elem.click() # 검사결과페이지로 이동한다

# %%
# imdb에서 영화정보를 크롤링해서 출력하시오..
# https://m.imdb.com/chart/top/?ref_=nv_mv_250

# ranking
# 제목
# 연도
# rate
# --------
# ranking
# 제목
# 연도
# rate
# --------

from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

url = "https://m.imdb.com/chart/top/?ref_=nv_mv_250"

# 크롬드라이버 열기
driver = webdriver.Chrome()
# url 열기
driver.get(url)

time.sleep(1)

################################
html = driver.page_source

# 웹 스크립트에서 원하는 콘텐츠를 추출
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
# 원하는 콘텐츠가 있는 경로
path = "#__next > main > div > div.ipc-page-content-container.ipc-page-content-container--center > section > div > div.ipc-page-grid.ipc-page-grid--bias-left > div > ul > li"
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# d:\BookExample_Python\Lecture02\Tranning\2023_11_29.ipynb Cell 8 line 3
#      <a href='vscode-notebook-cell:/d%3A/BookExample_Python/Lecture02/Tranning/2023_11_29.ipynb#X11sZmlsZQ%3D%3D?line=28'>29</a> time.sleep(1)
#      <a href='vscode-notebook-cell:/d%3A/BookExample_Python/Lecture02/Tranning/2023_11_29.ipynb#X11sZmlsZQ%3D%3D?line=30'>31</a> ################################
# ---> <a href='vscode-notebook-cell:/d%3A/BookExample_Python/Lecture02/Tranning/2023_11_29.ipynb#X11sZmlsZQ%3D%3D?line=31'>32</a> html = driver.page_source
#      <a href='vscode-notebook-cell:/d%3A/BookExample_Python/Lecture02/Tranning/2023_11_29.ipynb#X11sZmlsZQ%3D%3D?line=33'>34</a> # 웹 스크립트에서 원하는 콘텐츠를 추출
#      <a href='vscode-notebook-cell:/d%3A/BookExample_Python/Lecture02/Tranning/2023_11_29.ipynb#X11sZmlsZQ%3D%3D?line=34'>35</a> soup = BeautifulSoup(html, 'html.parser')
#
# File c:\Users\GJ\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:448, in WebDriver.page_source(self)
#     439 @property
#     440 def page_source(self) -> str:
#     441     """Gets the source of the current page.
#     442
#     443     :Usage:
#    (...)
#     446             driver.page_source
#     447     """
# --> 448     return self.execute(Command.GET_PAGE_SOURCE)["value"]
#
# File c:\Users\GJ\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File c:\Users\GJ\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=119.0.6045.161)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF665BE82B2+55298]
# 	(No symbol) [0x00007FF665B55E02]
# 	(No symbol) [0x00007FF665A105AB]
# 	(No symbol) [0x00007FF6659F0038]
# 	(No symbol) [0x00007FF665A76BC7]
# 	(No symbol) [0x00007FF665A8A15F]
# 	(No symbol) [0x00007FF665A71E83]
# 	(No symbol) [0x00007FF665A4670A]
# 	(No symbol) [0x00007FF665A47964]
# 	GetHandleVerifier [0x00007FF665F60AAB+3694587]
# 	GetHandleVerifier [0x00007FF665FB728E+4048862]
# 	GetHandleVerifier [0x00007FF665FAF173+4015811]
# 	GetHandleVerifier [0x00007FF665C847D6+695590]
# 	(No symbol) [0x00007FF665B60CE8]
# 	(No symbol) [0x00007FF665B5CF34]
# 	(No symbol) [0x00007FF665B5D062]
# 	(No symbol) [0x00007FF665B4D3A3]
# 	BaseThreadInitThunk [0x00007FFB60CE7344+20]
# 	RtlUserThreadStart [0x00007FFB613A26B1+33]

# %%
# ranking
# 제목
# 연도
# rate

movie_list = []

for item in soup.select(path):
    # name 가져오기
    name = item.select("div.ipc-title.ipc-title--base.ipc-title--title.ipc-title-link-no-icon.ipc-title--on-textPrimary.sc-479faa3c-9.dkLVoC.cli-title > a > h3")
    
    # span 내용 가져오기
    newList = item.select("span")
    
    # 각 내용에 맞는 리스트 값 가져오기
    movie_ranking = name[0].text.split()[0]
    movie_name = name[0].text.split()[1]
    movie_year = newList[1].text
    movie_rate = newList[4].text[:3]
   
    # 추가하기
    movie_list.append({"ranking":movie_ranking, "name" : movie_name, "year" : movie_year, "rate":movie_rate})
   
for item in movie_list:
    print(item)
# Out:
# {'ranking': '1.', 'name': '쇼생크', 'year': '1994', 'rate': '9.3'}
# {'ranking': '2.', 'name': 'Daeboo', 'year': '1972', 'rate': '9.2'}
# {'ranking': '3.', 'name': '다크', 'year': '2008', 'rate': '9.0'}
# {'ranking': '4.', 'name': 'The', 'year': '1974', 'rate': '9.0'}
# {'ranking': '5.', 'name': '12명의', 'year': '1957', 'rate': '9.0'}
# {'ranking': '6.', 'name': '쉰들러', 'year': '1993', 'rate': '9.0'}
# {'ranking': '7.', 'name': '반지의', 'year': '2003', 'rate': '9.0'}
# {'ranking': '8.', 'name': '펄프', 'year': '1994', 'rate': '8.9'}
# {'ranking': '9.', 'name': '반지의', 'year': '2001', 'rate': '8.8'}
# {'ranking': '10.', 'name': '석양의', 'year': '1966', 'rate': '8.8'}
# {'ranking': '11.', 'name': '포레스트', 'year': '1994', 'rate': '8.8'}
# {'ranking': '12.', 'name': '파이트', 'year': '1999', 'rate': '8.8'}
# {'ranking': '13.', 'name': 'The', 'year': '2002', 'rate': '8.8'}
# {'ranking': '14.', 'name': '인셉션', 'year': '2010', 'rate': '8.8'}
# {'ranking': '15.', 'name': '스타워즈', 'year': '1980', 'rate': '8.7'}
# {'ranking': '16.', 'name': '매트릭스', 'year': '1999', 'rate': '8.7'}
# {'ranking': '17.', 'name': '좋은', 'year': '1990', 'rate': '8.7'}
# {'ranking': '18.', 'name': '뻐꾸기', 'year': '1975', 'rate': '8.7'}
# {'ranking': '19.', 'name': '세븐', 'year': '1995', 'rate': '8.6'}
# {'ranking': '20.', 'name': '멋진', 'year': '1946', 'rate': '8.6'}
# {'ranking': '21.', 'name': '7인의', 'year': '1954', 'rate': '8.6'}
# {'ranking': '22.', 'name': '인터스텔라', 'year': '2014', 'rate': '8.7'}
# {'ranking': '23.', 'name': '양들의', 'year': '1991', 'rate': '8.6'}
# {'ranking': '24.', 'name': '라이언', 'year': '1998', 'rate': '8.6'}
# {'ranking': '25.', 'name': '시티', 'year': '2002', 'rate': '8.6'}
# {'ranking': '26.', 'name': 'La', 'year': '1997', 'rate': '8.6'}
# {'ranking': '27.', 'name': '그린', 'year': '1999', 'rate': '8.6'}
# {'ranking': '28.', 'name': 'Spider-Man:', 'year': '2023', 'rate': '8.7'}
# {'ranking': '29.', 'name': 'Star', 'year': '1977', 'rate': '8.6'}
# {'ranking': '30.', 'name': 'Terminator', 'year': '1991', 'rate': '8.6'}
# {'ranking': '31.', 'name': '빽', 'year': '1985', 'rate': '8.5'}
# {'ranking': '32.', 'name': '센과', 'year': '2001', 'rate': '8.6'}
# {'ranking': '33.', 'name': '피아니스트', 'year': '2002', 'rate': '8.5'}
# {'ranking': '34.', 'name': '싸이코', 'year': '1960', 'rate': '8.5'}
# {'ranking': '35.', 'name': 'Gisaengchung', 'year': '2019', 'rate': '8.5'}
# {'ranking': '36.', 'name': '글래디에이터', 'year': '2000', 'rate': '8.5'}
# {'ranking': '37.', 'name': '라이온', 'year': '1994', 'rate': '8.5'}
# {'ranking': '38.', 'name': '레옹', 'year': '1994', 'rate': '8.5'}
# {'ranking': '39.', 'name': '아메리칸', 'year': '1998', 'rate': '8.5'}
# {'ranking': '40.', 'name': '디파티드', 'year': '2006', 'rate': '8.5'}
# {'ranking': '41.', 'name': '위플래쉬', 'year': '2014', 'rate': '8.5'}
# {'ranking': '42.', 'name': '프레스티지', 'year': '2006', 'rate': '8.5'}
# {'ranking': '43.', 'name': '유주얼', 'year': '1995', 'rate': '8.5'}
# {'ranking': '44.', 'name': '반딧불이의', 'year': '1988', 'rate': '8.5'}
# {'ranking': '45.', 'name': 'Seppuku', 'year': '1962', 'rate': '8.6'}
# {'ranking': '46.', 'name': '카사블랑카', 'year': '1942', 'rate': '8.5'}
# {'ranking': '47.', 'name': '언터처블:', 'year': '2011', 'rate': '8.5'}
# {'ranking': '48.', 'name': '모던', 'year': '1936', 'rate': '8.5'}
# {'ranking': '49.', 'name': '시네마', 'year': '1988', 'rate': '8.5'}
# {'ranking': '50.', 'name': '원스', 'year': '1968', 'rate': '8.5'}
# {'ranking': '51.', 'name': '이창', 'year': '1954', 'rate': '8.5'}
# {'ranking': '52.', 'name': '에이리언', 'year': '1979', 'rate': '8.5'}
# {'ranking': '53.', 'name': 'City', 'year': '1931', 'rate': '8.5'}
# {'ranking': '54.', 'name': '지옥의', 'year': '1979', 'rate': '8.4'}
# {'ranking': '55.', 'name': '장고:', 'year': '2012', 'rate': '8.5'}
# {'ranking': '56.', 'name': '메멘토', 'year': '2000', 'rate': '8.4'}
# {'ranking': '57.', 'name': '레이더스', 'year': '1981', 'rate': '8.4'}
# {'ranking': '58.', 'name': '월-E', 'year': '2008', 'rate': '8.4'}
# {'ranking': '59.', 'name': '타인의', 'year': '2006', 'rate': '8.4'}
# {'ranking': '60.', 'name': 'Oppenheimer', 'year': '2023', 'rate': '8.5'}
# {'ranking': '61.', 'name': 'Sunset', 'year': '1950', 'rate': '8.4'}
# {'ranking': '62.', 'name': 'Paths', 'year': '1957', 'rate': '8.4'}
# {'ranking': '63.', 'name': '어벤져스:', 'year': '2018', 'rate': '8.4'}
# {'ranking': '64.', 'name': '샤이닝', 'year': '1980', 'rate': '8.4'}
# {'ranking': '65.', 'name': 'The', 'year': '1940', 'rate': '8.4'}
# {'ranking': '66.', 'name': '스파이더맨:', 'year': '2018', 'rate': '8.4'}
# {'ranking': '67.', 'name': 'Witness', 'year': '1957', 'rate': '8.4'}
# {'ranking': '68.', 'name': 'Aliens', 'year': '1986', 'rate': '8.4'}
# {'ranking': '69.', 'name': '바스터즈:', 'year': '2009', 'rate': '8.4'}
# {'ranking': '70.', 'name': 'Dakeu', 'year': '2012', 'rate': '8.4'}
# {'ranking': '71.', 'name': '아메리칸', 'year': '1999', 'rate': '8.3'}
# {'ranking': '72.', 'name': 'Dr.', 'year': '1964', 'rate': '8.4'}
# {'ranking': '73.', 'name': 'Oldeuboi', 'year': '2003', 'rate': '8.4'}
# {'ranking': '74.', 'name': '코코', 'year': '2017', 'rate': '8.4'}
# {'ranking': '75.', 'name': '아마데우스', 'year': '1984', 'rate': '8.4'}
# {'ranking': '76.', 'name': 'Toy', 'year': '1995', 'rate': '8.3'}
# {'ranking': '77.', 'name': 'The', 'year': '1981', 'rate': '8.4'}
# {'ranking': '78.', 'name': 'Braveheart', 'year': '1995', 'rate': '8.3'}
# {'ranking': '79.', 'name': '어벤져스:', 'year': '2019', 'rate': '8.4'}
# {'ranking': '80.', 'name': '조커', 'year': '2019', 'rate': '8.4'}
# {'ranking': '81.', 'name': 'Mononoke-hime', 'year': '1997', 'rate': '8.3'}
# {'ranking': '82.', 'name': '굿', 'year': '1997', 'rate': '8.3'}
# {'ranking': '83.', 'name': 'Neoui', 'year': '2016', 'rate': '8.4'}
# {'ranking': '84.', 'name': '원스', 'year': '1984', 'rate': '8.3'}
# {'ranking': '85.', 'name': '천국과', 'year': '1963', 'rate': '8.4'}
# {'ranking': '86.', 'name': '세', 'year': '2009', 'rate': '8.4'}
# {'ranking': '87.', 'name': '사랑은', 'year': '1952', 'rate': '8.3'}
# {'ranking': '88.', 'name': '가버나움', 'year': '2018', 'rate': '8.4'}
# {'ranking': '89.', 'name': '레퀴엠', 'year': '2000', 'rate': '8.3'}
# {'ranking': '90.', 'name': '컴', 'year': '1985', 'rate': '8.4'}
# {'ranking': '91.', 'name': '토이', 'year': '2010', 'rate': '8.3'}
# {'ranking': '92.', 'name': 'Star', 'year': '1983', 'rate': '8.3'}
# {'ranking': '93.', 'name': '이터널', 'year': '2004', 'rate': '8.3'}
# {'ranking': '94.', 'name': '2001:', 'year': '1968', 'rate': '8.3'}
# {'ranking': '95.', 'name': '더', 'year': '2012', 'rate': '8.3'}
# {'ranking': '96.', 'name': '저수지의', 'year': '1992', 'rate': '8.3'}
# {'ranking': '97.', 'name': '이키루', 'year': '1952', 'rate': '8.3'}
# {'ranking': '98.', 'name': 'Lawrence', 'year': '1962', 'rate': '8.3'}
# {'ranking': '99.', 'name': 'The', 'year': '1960', 'rate': '8.3'}
# {'ranking': '100.', 'name': '시민', 'year': '1941', 'rate': '8.3'}
# {'ranking': '101.', 'name': 'M', 'year': '1931', 'rate': '8.3'}
# {'ranking': '102.', 'name': 'Bugbugseolo', 'year': '1959', 'rate': '8.3'}
# {'ranking': '103.', 'name': 'Hyeongijeung', 'year': '1958', 'rate': '8.3'}
# {'ranking': '104.', 'name': 'Double', 'year': '1944', 'rate': '8.3'}
# {'ranking': '105.', 'name': '아멜리에', 'year': '2001', 'rate': '8.3'}
# {'ranking': '106.', 'name': '스카페이스', 'year': '1983', 'rate': '8.3'}
# {'ranking': '107.', 'name': 'Metal', 'year': '1987', 'rate': '8.3'}
# {'ranking': '108.', 'name': '그을린', 'year': '2010', 'rate': '8.3'}
# {'ranking': '109.', 'name': '시계태엽', 'year': '1971', 'rate': '8.3'}
# {'ranking': '110.', 'name': '히트', 'year': '1995', 'rate': '8.3'}
# {'ranking': '111.', 'name': '업', 'year': '2009', 'rate': '8.3'}
# {'ranking': '112.', 'name': 'To', 'year': '1962', 'rate': '8.3'}
# {'ranking': '113.', 'name': 'Hamilton', 'year': '2020', 'rate': '8.3'}
# {'ranking': '114.', 'name': 'The', 'year': '1973', 'rate': '8.3'}
# {'ranking': '115.', 'name': 'Jodaeiye', 'year': '2011', 'rate': '8.3'}
# {'ranking': '116.', 'name': 'Indiana', 'year': '1989', 'rate': '8.2'}
# {'ranking': '117.', 'name': 'Metropolis', 'year': '1927', 'rate': '8.3'}
# {'ranking': '118.', 'name': '다이', 'year': '1988', 'rate': '8.2'}
# {'ranking': '119.', 'name': 'Like', 'year': '2007', 'rate': '8.3'}
# {'ranking': '120.', 'name': 'Snatch', 'year': '2000', 'rate': '8.2'}
# {'ranking': '121.', 'name': 'Bicycle', 'year': '1948', 'rate': '8.3'}
# {'ranking': '122.', 'name': 'L.A.', 'year': '1997', 'rate': '8.2'}
# {'ranking': '123.', 'name': 'Taxi', 'year': '1976', 'rate': '8.2'}
# {'ranking': '124.', 'name': '1917', 'year': '2019', 'rate': '8.2'}
# {'ranking': '125.', 'name': 'Downfall', 'year': '2004', 'rate': '8.2'}
# {'ranking': '126.', 'name': 'Dangal', 'year': '2016', 'rate': '8.3'}
# {'ranking': '127.', 'name': 'For', 'year': '1965', 'rate': '8.2'}
# {'ranking': '128.', 'name': '배트맨', 'year': '2005', 'rate': '8.2'}
# {'ranking': '129.', 'name': '탑건:', 'year': '2022', 'rate': '8.3'}
# {'ranking': '130.', 'name': 'Some', 'year': '1959', 'rate': '8.2'}
# {'ranking': '131.', 'name': 'The', 'year': '1921', 'rate': '8.2'}
# {'ranking': '132.', 'name': '더', 'year': '2013', 'rate': '8.2'}
# {'ranking': '133.', 'name': '더', 'year': '2020', 'rate': '8.2'}
# {'ranking': '134.', 'name': '그린', 'year': '2018', 'rate': '8.2'}
# {'ranking': '135.', 'name': 'Eveeui', 'year': '1950', 'rate': '8.2'}
# {'ranking': '136.', 'name': '뉘른베르크의', 'year': '1961', 'rate': '8.3'}
# {'ranking': '137.', 'name': '트루먼', 'year': '1998', 'rate': '8.2'}
# {'ranking': '138.', 'name': '데어', 'year': '2007', 'rate': '8.2'}
# {'ranking': '139.', 'name': '카지노', 'year': '1995', 'rate': '8.2'}
# {'ranking': '140.', 'name': '셔터', 'year': '2010', 'rate': '8.2'}
# {'ranking': '141.', 'name': 'Ran', 'year': '1985', 'rate': '8.2'}
# {'ranking': '142.', 'name': '판의', 'year': '2006', 'rate': '8.2'}
# {'ranking': '143.', 'name': 'Jyuragi', 'year': '1993', 'rate': '8.2'}
# {'ranking': '144.', 'name': '식스', 'year': '1999', 'rate': '8.2'}
# {'ranking': '145.', 'name': 'Unforgiven', 'year': '1992', 'rate': '8.2'}
# {'ranking': '146.', 'name': 'A', 'year': '2001', 'rate': '8.2'}
# {'ranking': '147.', 'name': '노인을', 'year': '2007', 'rate': '8.2'}
# {'ranking': '148.', 'name': 'Yôjinbô', 'year': '1961', 'rate': '8.2'}
# {'ranking': '149.', 'name': 'The', 'year': '1948', 'rate': '8.2'}
# {'ranking': '150.', 'name': '킬', 'year': '2003', 'rate': '8.2'}
# {'ranking': '151.', 'name': 'The', 'year': '1982', 'rate': '8.2'}
# {'ranking': '152.', 'name': 'Monty', 'year': '1975', 'rate': '8.2'}
# {'ranking': '153.', 'name': 'The', 'year': '1963', 'rate': '8.2'}
# {'ranking': '154.', 'name': 'Finding', 'year': '2003', 'rate': '8.2'}
# {'ranking': '155.', 'name': '라쇼몽', 'year': '1950', 'rate': '8.2'}
# {'ranking': '156.', 'name': 'The', 'year': '1980', 'rate': '8.2'}
# {'ranking': '157.', 'name': 'Chinatown', 'year': '1974', 'rate': '8.2'}
# {'ranking': '158.', 'name': 'Howlui', 'year': '2004', 'rate': '8.2'}
# {'ranking': '159.', 'name': 'Dial', 'year': '1954', 'rate': '8.2'}
# {'ranking': '160.', 'name': '바람과', 'year': '1939', 'rate': '8.2'}
# {'ranking': '161.', 'name': '브이', 'year': '2005', 'rate': '8.2'}
# {'ranking': '162.', 'name': '프리즈너스', 'year': '2013', 'rate': '8.1'}
# {'ranking': '163.', 'name': 'Raging', 'year': '1980', 'rate': '8.1'}
# {'ranking': '164.', 'name': 'Lock,', 'year': '1998', 'rate': '8.1'}
# {'ranking': '165.', 'name': 'El', 'year': '2009', 'rate': '8.2'}
# {'ranking': '166.', 'name': '인사이드', 'year': '2015', 'rate': '8.1'}
# {'ranking': '167.', 'name': '스파이더맨:', 'year': '2021', 'rate': '8.2'}
# {'ranking': '168.', 'name': '쓰리', 'year': '2017', 'rate': '8.1'}
# {'ranking': '169.', 'name': 'Trainspotting', 'year': '1996', 'rate': '8.1'}
# {'ranking': '170.', 'name': 'The', 'year': '1957', 'rate': '8.1'}
# {'ranking': '171.', 'name': '파고', 'year': '1996', 'rate': '8.1'}
# {'ranking': '172.', 'name': 'Warrior', 'year': '2011', 'rate': '8.1'}
# {'ranking': '173.', 'name': '캐치', 'year': '2002', 'rate': '8.1'}
# {'ranking': '174.', 'name': '그랜', 'year': '2008', 'rate': '8.1'}
# {'ranking': '175.', 'name': 'Tonari', 'year': '1988', 'rate': '8.1'}
# {'ranking': '176.', 'name': '클라우스', 'year': '2019', 'rate': '8.2'}
# {'ranking': '177.', 'name': '밀리언', 'year': '2004', 'rate': '8.1'}
# {'ranking': '178.', 'name': 'Haeri', 'year': '2011', 'rate': '8.1'}
# {'ranking': '179.', 'name': 'Children', 'year': '1997', 'rate': '8.2'}
# {'ranking': '180.', 'name': '블레이드', 'year': '1982', 'rate': '8.1'}
# {'ranking': '181.', 'name': '12', 'year': '2013', 'rate': '8.1'}
# {'ranking': '182.', 'name': '비포', 'year': '1995', 'rate': '8.1'}
# {'ranking': '183.', 'name': 'The', 'year': '2014', 'rate': '8.1'}
# {'ranking': '184.', 'name': 'Ben-Hur', 'year': '1959', 'rate': '8.1'}
# {'ranking': '185.', 'name': 'The', 'year': '1925', 'rate': '8.1'}
# {'ranking': '186.', 'name': 'Gone', 'year': '2014', 'rate': '8.1'}
# {'ranking': '187.', 'name': 'Barry', 'year': '1975', 'rate': '8.1'}
# {'ranking': '188.', 'name': '핵소', 'year': '2016', 'rate': '8.1'}
# {'ranking': '189.', 'name': 'In', 'year': '1993', 'rate': '8.1'}
# {'ranking': '190.', 'name': 'On', 'year': '1954', 'rate': '8.1'}
# {'ranking': '191.', 'name': 'Salinui', 'year': '2003', 'rate': '8.1'}
# {'ranking': '192.', 'name': 'The', 'year': '1926', 'rate': '8.1'}
# {'ranking': '193.', 'name': 'The', 'year': '1978', 'rate': '8.1'}
# {'ranking': '194.', 'name': 'Smultronstället', 'year': '1957', 'rate': '8.1'}
# {'ranking': '195.', 'name': 'Waildeu', 'year': '2014', 'rate': '8.1'}
# {'ranking': '196.', 'name': 'The', 'year': '1949', 'rate': '8.1'}
# {'ranking': '197.', 'name': '죽은', 'year': '1989', 'rate': '8.1'}
# {'ranking': '198.', 'name': 'Le', 'year': '1953', 'rate': '8.2'}
# {'ranking': '199.', 'name': 'Sherlock', 'year': '1924', 'rate': '8.2'}
# {'ranking': '200.', 'name': '매드맥스:', 'year': '2015', 'rate': '8.1'}
# {'ranking': '201.', 'name': 'Monsters,', 'year': '2001', 'rate': '8.1'}
# {'ranking': '202.', 'name': 'Mr.', 'year': '1939', 'rate': '8.1'}
# {'ranking': '203.', 'name': '죠스', 'year': '1975', 'rate': '8.1'}
# {'ranking': '204.', 'name': '드래곤', 'year': '2010', 'rate': '8.1'}
# {'ranking': '205.', 'name': 'Mary', 'year': '2009', 'rate': '8.1'}
# {'ranking': '206.', 'name': 'Ford', 'year': '2019', 'rate': '8.1'}
# {'ranking': '207.', 'name': 'The', 'year': '1957', 'rate': '8.1'}
# {'ranking': '208.', 'name': 'Room', 'year': '2015', 'rate': '8.1'}
# {'ranking': '209.', 'name': '위대한', 'year': '1998', 'rate': '8.1'}
# {'ranking': '210.', 'name': '라따뚜이', 'year': '2007', 'rate': '8.1'}
# {'ranking': '211.', 'name': '동경', 'year': '1953', 'rate': '8.1'}
# {'ranking': '212.', 'name': '록키', 'year': '1976', 'rate': '8.1'}
# {'ranking': '213.', 'name': 'Hotel', 'year': '2004', 'rate': '8.1'}
# {'ranking': '214.', 'name': '로건', 'year': '2017', 'rate': '8.1'}
# {'ranking': '215.', 'name': '스포트라이트', 'year': '2015', 'rate': '8.1'}
# {'ranking': '216.', 'name': 'Platoon', 'year': '1986', 'rate': '8.1'}
# {'ranking': '217.', 'name': 'La', 'year': '1928', 'rate': '8.1'}
# {'ranking': '218.', 'name': '터미네이터', 'year': '1984', 'rate': '8.1'}
# {'ranking': '219.', 'name': 'Jai', 'year': '2021', 'rate': '8.8'}
# {'ranking': '220.', 'name': 'Before', 'year': '2004', 'rate': '8.1'}
# {'ranking': '221.', 'name': 'Rush', 'year': '2013', 'rate': '8.1'}
# {'ranking': '222.', 'name': 'Network', 'year': '1976', 'rate': '8.1'}
# {'ranking': '223.', 'name': 'The', 'year': '1946', 'rate': '8.1'}
# {'ranking': '224.', 'name': '엑소시스트:', 'year': '1973', 'rate': '8.1'}
# {'ranking': '225.', 'name': 'Stand', 'year': '1986', 'rate': '8.1'}
# {'ranking': '226.', 'name': 'La', 'year': '1995', 'rate': '8.1'}
# {'ranking': '227.', 'name': '캐리비안의', 'year': '2003', 'rate': '8.1'}
# {'ranking': '228.', 'name': '오즈의', 'year': '1939', 'rate': '8.1'}
# {'ranking': '229.', 'name': 'The', 'year': '2004', 'rate': '8.0'}
# {'ranking': '230.', 'name': 'Into', 'year': '2007', 'rate': '8.1'}
# {'ranking': '231.', 'name': 'Hachi:', 'year': '2009', 'rate': '8.1'}
# {'ranking': '232.', 'name': 'To', 'year': '1942', 'rate': '8.2'}
# {'ranking': '233.', 'name': 'Ahgassi', 'year': '2016', 'rate': '8.1'}
# {'ranking': '234.', 'name': 'Babam', 'year': '2005', 'rate': '8.2'}
# {'ranking': '235.', 'name': 'La', 'year': '1966', 'rate': '8.1'}
# {'ranking': '236.', 'name': '사랑의', 'year': '1993', 'rate': '8.0'}
# {'ranking': '237.', 'name': 'The', 'year': '1940', 'rate': '8.1'}
# {'ranking': '238.', 'name': 'Amores', 'year': '2000', 'rate': '8.1'}
# {'ranking': '239.', 'name': '사운드', 'year': '1965', 'rate': '8.1'}
# {'ranking': '240.', 'name': 'Rebecca', 'year': '1940', 'rate': '8.1'}
# {'ranking': '241.', 'name': 'Cool', 'year': '1967', 'rate': '8.1'}
# {'ranking': '242.', 'name': 'The', 'year': '1999', 'rate': '8.1'}
# {'ranking': '243.', 'name': 'Pather', 'year': '1955', 'rate': '8.2'}
# {'ranking': '244.', 'name': '어느', 'year': '1934', 'rate': '8.1'}
# {'ranking': '245.', 'name': '헬프', 'year': '2011', 'rate': '8.1'}
# {'ranking': '246.', 'name': 'The', 'year': '1959', 'rate': '8.1'}
# {'ranking': '247.', 'name': '알라딘', 'year': '1992', 'rate': '8.0'}
# {'ranking': '248.', 'name': 'Dances', 'year': '1990', 'rate': '8.0'}
# {'ranking': '249.', 'name': 'Life', 'year': '1979', 'rate': '8.0'}
# {'ranking': '250.', 'name': '와시푸르의', 'year': '2012', 'rate': '8.2'}

# %%
# 수동 다나와 사이트에 회원가입 > 로그인 > 관심상품등록
# selenium : 로그인 > 관심상품 목록 출력... 

from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

url = "https://www.danawa.com/"

# 크롬드라이버 열기
driver = webdriver.Chrome()
# url 열기
driver.get(url)

time.sleep(1)

id = "dlehrb103@naver.com"
pw = "wjdqhqhdks1!"

### 로그인 화면 접속
elem = driver.find_element(By.CSS_SELECTOR,"#danawa_header > div > div > div.main-header__banner > div.main-header__user > div:nth-child(5) > a")
elem.click()

time.sleep(1)

### 로그인 단계
# id 입력
elem = driver.find_element(By.CSS_SELECTOR,"#danawa-member-login-input-id")
elem.send_keys(id)

# pw 입력
elem = driver.find_element(By.CSS_SELECTOR,"#danawa-member-login-input-pwd")
elem.send_keys(pw)

# 로그인 버튼 실행
elem = driver.find_element(By.CSS_SELECTOR,"#danawa-member-login-loginButton")
elem.click()

time.sleep(1)

### 관심 목록 들억라기
elem = driver.find_element(By.CSS_SELECTOR,"#danawa_header > div > div > div.main-header__banner > div.main-header__user > div:nth-child(4) > a")
elem.click()

time.sleep(1)

# %%
# 파싱
html = driver.page_source
soup = BeautifulSoup(html, "html.parser")

# 관심 목록 상품 목록
path = "#wishProductListArea > table > tbody > tr"

# 값 가져와 출력하기
for item in soup.select(path):
    print(item.select('div.tit')[0].text.strip())
    print(item.select('em.num')[0].text.strip())
    print(item.select('div.sub_info.clear > dl > dd')[0].text.strip())
    print()
# Out:
# 피씨스토어 베스트 게이밍 7500F RTX4060 (16GB, M.2 500GB)
# 1,039,000
# 2023.10
#
# 삼성전자 DDR4-3200 (16GB)
# 40,540
# 2020.07
#
# 재원씨앤씨 아이로드 TX1 2채널 (32GB)
# 88,200
# 2023.09

# %%
# 아마존의 best seller 상품 출력
# url = 'https://www.amazon.com/Best-Sellers-Appliances/zgbs/appliances/ref=zg_bs_nav_0'

from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

url = "https://www.amazon.com/Best-Sellers-Appliances/zgbs/appliances/ref=zg_bs_nav_0"

# 크롬드라이버 열기
driver = webdriver.Chrome()
# url 열기
driver.get(url)
# Out:
# []

# %%
html = driver.page_source
soup = BeautifulSoup(html, "html.parser")

path = "div.p13n-desktop-grid > div > div > div"


for item in soup.select(path):
    try:
        name = item.select('a.a-link-normal > span > div')[0].text.strip()
    except:
        pass
