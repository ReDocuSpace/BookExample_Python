# %%
import requests
from bs4 import BeautifulSoup

html = """
<body>
<div>
    <div class='snack'>
        <p id='first'> 양파링</p>
        <p id='second'> 새우깡</p>
        <p> 초코파이</p>
        <p class='sweet'> 맛동산 </p>

    <div class='icecream'>
        <p> 빵빠레</p>
        <p id='third'> 죠스바</p>
        <p> 꼬깔콘</p>
        <p class='sweet'> 쭈쭈바</p>
    </div>
</div>
</body>
"""

soup = BeautifulSoup(html, 'html.parser')

# 양파링

path = "div > div.snack > p#first"

soup.select(path)[0].text
# Out:
# ' 양파링'

# %%
# 죠스바
path = "div > div.icecream > p#third"

soup.select(path)[0].text
# Out:
# ' 죠스바'

# %%
# 맛동산, 쭈꾸바

path = "div > p.sweet"

for i in soup.select(path):
    print(i.text)
# Out:
#  맛동산
#  쭈쭈바

# %%
# snack의 모든 이름을 출력

path = "div > div.snack > p"

for i in soup.select(path):
    print(i.text)
# Out:
#  양파링
#  새우깡
#  초코파이
#  맛동산

# %%
# nate에서 검색 후 뉴스페이지에서 
# 제목 : ...
# 서머리 : .....

# 제목 : ...
# 서머리 : ....

import requests
from bs4 import BeautifulSoup

select = input("제목을 작성하시오 : ")

url = f"https://search.daum.net/nate?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q={select}"

res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')

path = "div.c-item-content > div.item-bundle-mid > div"
#dnsColl > div:nth-child(1) > ul > li:nth-child(1) > div.c-item-content > div.item-bundle-mid


for i, item in enumerate(soup.select(path)):
    if i % 2 == 0:
        print("제목 : ", item.text)
    else:
        print("서머리 : ", item.text)
        print()
# Out:
# <Response [200]>

# %%
main_path = "div.c-item-content > div.item-bundle-mid"
title_path = "div.c-item-content > div.item-bundle-mid > div.item-title"
contents_path = "div.c-item-content > div.item-bundle-mid > div.item-contents"

for item in soup.select(main_path):
    title = item.select(title_path)
    summary = item.select(contents_path)
    
    print(title[0].text)
    print(summary[0].text)
    print()
    
    
#soup.select(contents_path)[0].text
# Out:
#    [뉴스1 ★]‘군 입대 앞둔’ 뷔, 머리 자른 애교 곰돌이…울지마 아미
#    군 입대를 앞둔 방탄소년단(BTS) 뷔의 짧아진 헤어스타일이 눈길을 끈다. ⓒ News1 권현진 기자 방탄소년단(BTS) 뷔가 해외 일정을 위해 27일 인천국제공항을 통해 영국 런던으로 출국하며 애교 인사를 하고 있다. ⓒ News1 권현진 기자 방탄소년단(BTS) 뷔가 해외...    2023.11.27
#
#    리아킴, ‘미나명 울지마’ [포토엔HD]
#    [뉴스엔 유용주 기자] 딥앤댑 미나명(왼쪽), 원밀리언 리아킴이 11월 17일 오전 서울 강남구 CGV청담씨네시티에서 열린 Mnet '스트릿 우먼 파이터2' 종영 간담회에 참석했다. 뉴스엔 유용주 yongju@ 기사제보 및 보도자료 newsen@newsen.com copyrightⓒ 뉴스엔...    2023.11.17
#
#    '울지 마 바보야' 도발→쿨하게 퇴장 당한 무리뉴 감독 '뒤늦은 후회'
#    [마이데일리 = 심재희 기자] '퇴장도 카리스마 넘치게! 하지만…' 역시 카리스마가 넘친다. 상대 도발도 시원시원하게 한다. 그리고 예상이라도 한 것처럼 심판의 레드카드를 받고 쿨하게 퇴장한다. '스페셜 원' 조제 무리뉴 AS 로마 감독이 레드카드를 받고 퇴장...    2023.10.23
#
#    중국, 길 잃은 어린이 가족 품으로
#    시민 제보가 접수되자마자 경찰이 현장에 출동합니다. 할아버지를 찾으며 서럽게 우는 어린이를 경찰이 달래는데요. [경찰 : "울지마! 왜 그래? (할아버지!) 할아버지가 없구나? 할아버지 찾아볼까?"] 경찰은 일단은 아이를 차에 태워 경찰서로 데려갑니다. 우는...    1시간전
#
#    [디패Go] "아이 해브, 다 가졌다"…아이브가 IVE한 순간들
#    리즈, 이서) "우리가 절친, 커플즈"(레이, 리즈) "비주얼, 인형즈"(이서, 원영) "지원이도 인형"(이서, 원영, 리즈) "콩순이 울지마"(레이, 가을) 아이브는 언제나 그랬듯, 다이브에게 달려갔습니다. 팬들의 애타는 앵콜 요청에 재등장했는데요. 무대 아래 객석...    2023.11.27
#
#    이대호, 야구선수 하겠단 초1 子에 "아프다 하지마, 뼈 부러진것도 아니고" 엄격
#    이해해주면 아이가 무너질까 생각한다"고 분석한 뒤 "아픈 것은 맞지만 야구선수 하려면 이겨내야 해!"라고 공감하는 것과 "울지도 마!"는 엄연히 다른 것이라 일침을 가했다. 또한 이대호의 마음에 자리 잡은 "강하게 버텨내야 한다"는 생각이 자녀들에게도 큰 영향...    2023.11.20
#
#    [정전 70년, 피란수도 부산] ㉟ 엑스포로 꽃피워야 할 유산(완)
#    등 헌신한 인물이다. 알로이시오 신부에게 유아세례를 받은 사람이 '남수단의 슈바이처'로 불리는 한국의 이태석 신부다. '울지마 톤즈'라는 영화로도 잘 알려진 이 신부는 가장 가난한 나라라는 남수단에서 의료봉사와 선교활동, 교육 활동을 하며 현지인들에게...    2023.11.25 탐사뉴스
#
#    '사당귀' 추성훈 "돌아가신 父 입관 때 금메달 드렸다" 울컥[★밤TView]
#    거다"라고 공감했다. 추성훈의 모친은 "아들, 딸! 있을 때 해달라. 없을 때 하는 건 다 필요 없다. 엄마 죽으면 울지마. 절대로 울지마라. 지금 또 생각나서 얘기한다. 야 아들 추성훈. 딸 낳아보니 알겠지, 엄마 마음을. 엄마는 그랬다. 빨간 띠 지금 처음으로 얘기...    2023.11.19
#
#    메달에 떨어진 눈물…김선우·정진화 울지마, 그래도 좋았어!
#    근대5종 전사들의 메달에 눈물이 떨어졌다. 24일 중국 푸양 인후 스포츠센터에서 19회 항저우 아시안게임 근대5종 여자 개인전 결승 시상식이 진행되고 있는 가운데 은메달을 딴 김선우가 아쉬워하고 있다(왼쪽). 같은 날 근대5종 남자 단체전 시상식에서 정진화가...    2023.09.25
#
#    "울지마" AG 3연패 좌절 이다빈, 그래도 충분히 값진 은메달
#    <저작권자(c) 연합뉴스, 무단 전재-재배포 금지> <저작권자(c) 연합뉴스, 무단 전재-재배포 금지> <저작권자(c) 연합뉴스, 무단 전재-재배포 금지> [스포츠조선 박찬준 기자]'한국 여자 태권도의 간판' 이다빈(27·서울시청)이 아쉽게 새로운 역사 문턱에서 눈물을...    2023.09.28

# %%
# nate에서 검색 후 뉴스페이지에서 
# 제목 : ...
# 서머리 : .....
# 언론사
# 날짜

import requests
from bs4 import BeautifulSoup

mainList = []
mainDic = {}

select = "안녕" #input("제목을 작성하시오 : ")

url = f"https://search.daum.net/nate?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q={select}"

res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')

main_path = "#dnsColl > div > ul > li"
company_path = "div.c-tit-doc > div.area_tit > div > a > strong > span"
#company_path = "div.c-tit-doc > div.area_tit > div > a"
title_path = "div.item-title"

contents_path = "div.item-contents > p"
content_href_path = "div.item-title > strong > a"
today_path = "div.c-item-content > div.item-bundle-mid > div.item-contents > span"
#dnsColl > div:nth-child(1) > ul > li:nth-child(1) > div.c-item-content > div.item-bundle-mid > div.item-title > strong > a
soup.select(main_path)

for i, item in enumerate(soup.select(main_path)):
    company = item.select(company_path)
    title = item.select(title_path)
    summary = item.select(contents_path)
    today = item.select(today_path)
    content_href = item.select(content_href_path)
    
    mainDic[i] = {"title" : title[0].text, "summary" : summary[0].text, "company" : company[0].text, "today" : today[0].text, "href" : content_href[0]['href']}
    mainList.append({"title" : title[0].text, "summary" : summary[0].text, "company" : company[0].text, "today" : today[0].text, "href" : content_href[0]['href']})
    
for key,value in mainDic.items():
    print(key + 1, "번")
    for key, item_value in value.items():
        print( key , " : ", item_value)
        
    print()
# Out:
# 1 번
# title  :     얼굴 없는 노래방차트 1위 가수 #안녕, 알고보니 '연봉 1억' 받는 대기업 직원
# summary  :    기자] 요즘 10대-20대에게 ’얼굴이 없어도‘ 아주 유명한 가수가 있다. 얼굴 없이 7년간 활동했던 가수 #안녕. '안녕'이라고 읽어야 하나, '샵안녕'이라고 읽어야 하나 모를 정도로 일반인들에게 익숙하지 않은 이름이지만 10대 20대 젊은 층이 애용하는 코노(코인...
# company  :  OSEN
# today  :   2023.11.07
# href  :  http://v.daum.net/v/20231107093520126
#
# 2 번
# title  :     이청아 "'연인' 각화, 만나기 어려운 캐릭터"...출연 비하인드 ('안녕하니')
# summary  :    채널 딩고(dingo)는 지난 22일 오후 8시 딩고 뮤직 공식 유튜브 채널을 통해 힐링 뮤직 토크쇼 '너의 밤은 안녕하니' 2화를 공개했다. '너의 밤은 안녕하니'는 고요한 밤에 듣는 라디오를 연상시키는, 따뜻하고 편안한 분위기 속에 진행되는 뮤직 토크쇼 프로그램...
# company  :  OSEN
# today  :   2023.11.23
# href  :  http://v.daum.net/v/20231123113322502
#
# 3 번
# title  :     [경남 주말&문화] 당신의 안녕을 염원하며…‘무수히 안녕’
# summary  :    [KBS 창원] [앵커] 경남 주말엔문화, 경남도립미술관이 올해 마지막 기획전, '무수히 안녕'을 내일(24일) 개막합니다. 모두의 '안녕'을 바라는 오랜 마음과 행위에 숨겨진 다양한 가치를 만나 보시죠. 진정은 기자입니다. [리포트] 불상과 나란히 등을 마주한 천사와...
# company  :  KBS
# today  :   2023.11.23
# href  :  http://v.daum.net/v/20231123220237776
#
# 4 번
# title  :     ‘안녕, 안녕! 안녕?’ 이시·제니박·심으뜸·김수지·김영석 단체전
# summary  :    안녕?’을 주제로 열리고 있는 이번 단체전은 청년 작가들의 작업을 통해 미래의 청년, 과거의 청년, 그리고 현재의 청년에게 안녕을 묻고자 기획됐다. ⓒ올리비아박 갤러리 ⓒ올리비아박 갤러리 전시를 통해 희망을 담고 긍정적인 메세지를 담은 작품들을 마주함...
# company  :  프레시안
# today  :   2023.11.13
# href  :  http://v.daum.net/v/20231113123103412
#
# 5 번
# title  :     경남도립미술관, 올해 마지막 기획전 '무수히 안녕' 24일 개막
# summary  :    (창원=연합뉴스) 김선경 기자 = 경남도립미술관은 올해 마지막 기획전 '무수히 안녕'을 오는 24일 개막한다고 19일 밝혔다. 이번 기획전은 누군가의 안녕을 바라는 염원에 숨겨진 다양한 가치를 동시대 미술과 전통공예를 통해 조명한다. 기획전에 참여하는 8명의...
# company  :  연합뉴스
# today  :   2023.11.19
# href  :  http://v.daum.net/v/20231119092106998
#
# 6 번
# title  :     “안녕? 청년밥차 민이라고 해” 개그맨 오지헌 대학교에 떴다[따만사]
# summary  :    오 간사는 2003년 KBS 공채 18기에 합격해 개그맨의 길에 들어선 지 20년이 됐다. 데뷔하자마자 그는 KBS2 개그콘서트를 통해 “안녕~! 난 민이라고 해”라는 유행어를 만들어 내기도 했다. 그는 “다른 개그맨들보다 쉽게 개그맨이 됐고 쉽게 성공을 해버렸다. 물론...
# company  :  동아일보
# today  :   2023.11.24 탐사뉴스
# href  :  http://v.daum.net/v/20231124140009057
#
# 7 번
# title  :     '복면가왕' 미다스의 손, 유리아·#안녕·효진·건지 꺾고 '가왕' 방어 [종합]
# summary  :    베스트셀러가 '사계', 잘 찍어가 '하루'를 선곡해 맞대결을 펼쳤다. 결과는 베스트셀러의 승리였고, 잘 찍어 정체는 #안녕이었다. #안녕은 데뷔 이후 최초로 얼굴을 공개했다며 "반도체 기업에서 엔지니어로 근무 중인 회사원이다. 연차를 내고 녹화에 왔다"라고 말...
# company  :  티브이데일리
# today  :   2023.11.26
# href  :  http://v.daum.net/v/20231126211607857
#
# 8 번
# title  :     이청아 "작품이 사랑받는 것=큰 복" 솔직 입담(너의 밤은 안녕하니)
# summary  :    채널 딩고(dingo)는 지난 22일 오후 8시 딩고 뮤직 공식 유튜브 채널을 통해 힐링 뮤직 토크쇼 '너의 밤은 안녕하니' 2화를 공개했다. '너의 밤은 안녕하니'는 고요한 밤에 듣는 라디오를 연상시키는, 따뜻하고 편안한 분위기 속에 진행되는 뮤직 토크쇼 프로그램...
# company  :  MBC연예
# today  :   2023.11.23
# href  :  http://v.daum.net/v/20231123103107515
#
# 9 번
# title  :     “안녕” 카라 박규리·니콜, 故 구하라 4주기에 전한 마음
# summary  :    그리움을 드러냈다. 박규리는 24일 자신의 인스타그램에 팬들이 구하라를 추억하며 지하철 역에 건 광고판 사진을 게재하며 “안녕”이라는 인사를 전했다. 광고판에는 생전 구하라가 무대에서 퍼포먼스를 하는 모습이 담긴 사진과 함께 ‘당신의 미소는 언제나 우리...
# company  :  OSEN
# today  :   2023.11.24
# href  :  http://v.daum.net/v/20231124181402786
#
# 10 번
# title  :     ‘이동국 딸’ 이재아, 테니스선수 은퇴 후 근황 “목발 영원히 안녕”
# summary  :    둘째 딸 이재아의 근황이 공개됐다. 지난 15일 이동국의 아내 이수진은 자신의 소셜네트워크서비스 계정에 “목발 보조기 영원히 안녕”이라는 문구와 함께 딸 이재아의 사진을 게재했다. 사진에는 이재아가 다리에 보조기를 차고 목발을 짚고 있는 모습이 그려졌다...
# company  :  뉴스엔
# today  :   2023.11.21
# href  :  http://v.daum.net/v/20231121130400986
#
#
#    얼굴 없는 노래방차트 1위 가수 #안녕, 알고보니 '연봉 1억' 받는 대기업 직원
#
# {'title': "   얼굴 없는 노래방차트 1위 가수 #안녕, 알고보니 '연봉 1억' 받는 대기업 직원   ", 'summary': "  기자] 요즘 10대-20대에게 ’얼굴이 없어도‘ 아주 유명한 가수가 있다. 얼굴 없이 7년간 활동했던 가수 #안녕. '안녕'이라고 읽어야 하나, '샵안녕'이라고 읽어야 하나 모를 정도로 일반인들에게 익숙하지 않은 이름이지만 10대 20대 젊은 층이 애용하는 코노(코인...  ", 'company': 'OSEN', 'today': ' 2023.11.07 ', 'href': 'http://v.daum.net/v/20231107093520126'}
# {'title': '   이청아 "\'연인\' 각화, 만나기 어려운 캐릭터"...출연 비하인드 (\'안녕하니\')   ', 'summary': "  채널 딩고(dingo)는 지난 22일 오후 8시 딩고 뮤직 공식 유튜브 채널을 통해 힐링 뮤직 토크쇼 '너의 밤은 안녕하니' 2화를 공개했다. '너의 밤은 안녕하니'는 고요한 밤에 듣는 라디오를 연상시키는, 따뜻하고 편안한 분위기 속에 진행되는 뮤직 토크쇼 프로그램...  ", 'company': 'OSEN', 'today': ' 2023.11.23 ', 'href': 'http://v.daum.net/v/20231123113322502'}
# {'title': '   [경남 주말&문화] 당신의 안녕을 염원하며…‘무수히 안녕’   ', 'summary': "  [KBS 창원] [앵커] 경남 주말엔문화, 경남도립미술관이 올해 마지막 기획전, '무수히 안녕'을 내일(24일) 개막합니다. 모두의 '안녕'을 바라는 오랜 마음과 행위에 숨겨진 다양한 가치를 만나 보시죠. 진정은 기자입니다. [리포트] 불상과 나란히 등을 마주한 천사와...  ", 'company': 'KBS', 'today': ' 2023.11.23 ', 'href': 'http://v.daum.net/v/20231123220237776'}
# {'title': '   ‘안녕, 안녕! 안녕?’ 이시·제니박·심으뜸·김수지·김영석 단체전   ', 'summary': '  안녕?’을 주제로 열리고 있는 이번 단체전은 청년 작가들의 작업을 통해 미래의 청년, 과거의 청년, 그리고 현재의 청년에게 안녕을 묻고자 기획됐다. ⓒ올리비아박 갤러리 ⓒ올리비아박 갤러리 전시를 통해 희망을 담고 긍정적인 메세지를 담은 작품들을 마주함...  ', 'company': '프레시안', 'today': ' 2023.11.13 ', 'href': 'http://v.daum.net/v/20231113123103412'}
# {'title': "   경남도립미술관, 올해 마지막 기획전 '무수히 안녕' 24일 개막   ", 'summary': "  (창원=연합뉴스) 김선경 기자 = 경남도립미술관은 올해 마지막 기획전 '무수히 안녕'을 오는 24일 개막한다고 19일 밝혔다. 이번 기획전은 누군가의 안녕을 바라는 염원에 숨겨진 다양한 가치를 동시대 미술과 전통공예를 통해 조명한다. 기획전에 참여하는 8명의...  ", 'company': '연합뉴스', 'today': ' 2023.11.19 ', 'href': 'http://v.daum.net/v/20231119092106998'}
# {'title': '   “안녕? 청년밥차 민이라고 해” 개그맨 오지헌 대학교에 떴다[따만사]   ', 'summary': '  오 간사는 2003년 KBS 공채 18기에 합격해 개그맨의 길에 들어선 지 20년이 됐다. 데뷔하자마자 그는 KBS2 개그콘서트를 통해 “안녕~! 난 민이라고 해”라는 유행어를 만들어 내기도 했다. 그는 “다른 개그맨들보다 쉽게 개그맨이 됐고 쉽게 성공을 해버렸다. 물론...  ', 'company': '동아일보', 'today': ' 2023.11.24 탐사뉴스 ', 'href': 'http://v.daum.net/v/20231124140009057'}
# {'title': "   '복면가왕' 미다스의 손, 유리아·#안녕·효진·건지 꺾고 '가왕' 방어 [종합]   ", 'summary': '  베스트셀러가 \'사계\', 잘 찍어가 \'하루\'를 선곡해 맞대결을 펼쳤다. 결과는 베스트셀러의 승리였고, 잘 찍어 정체는 #안녕이었다. #안녕은 데뷔 이후 최초로 얼굴을 공개했다며 "반도체 기업에서 엔지니어로 근무 중인 회사원이다. 연차를 내고 녹화에 왔다"라고 말...  ', 'company': '티브이데일리', 'today': ' 2023.11.26 ', 'href': 'http://v.daum.net/v/20231126211607857'}
# {'title': '   이청아 "작품이 사랑받는 것=큰 복" 솔직 입담(너의 밤은 안녕하니)   ', 'summary': "  채널 딩고(dingo)는 지난 22일 오후 8시 딩고 뮤직 공식 유튜브 채널을 통해 힐링 뮤직 토크쇼 '너의 밤은 안녕하니' 2화를 공개했다. '너의 밤은 안녕하니'는 고요한 밤에 듣는 라디오를 연상시키는, 따뜻하고 편안한 분위기 속에 진행되는 뮤직 토크쇼 프로그램...  ", 'company': 'MBC연예', 'today': ' 2023.11.23 ', 'href': 'http://v.daum.net/v/20231123103107515'}
# {'title': '   “안녕” 카라 박규리·니콜, 故 구하라 4주기에 전한 마음   ', 'summary': '  그리움을 드러냈다. 박규리는 24일 자신의 인스타그램에 팬들이 구하라를 추억하며 지하철 역에 건 광고판 사진을 게재하며 “안녕”이라는 인사를 전했다. 광고판에는 생전 구하라가 무대에서 퍼포먼스를 하는 모습이 담긴 사진과 함께 ‘당신의 미소는 언제나 우리...  ', 'company': 'OSEN', 'today': ' 2023.11.24 ', 'href': 'http://v.daum.net/v/20231124181402786'}
# {'title': '   ‘이동국 딸’ 이재아, 테니스선수 은퇴 후 근황 “목발 영원히 안녕”   ', 'summary': '  둘째 딸 이재아의 근황이 공개됐다. 지난 15일 이동국의 아내 이수진은 자신의 소셜네트워크서비스 계정에 “목발 보조기 영원히 안녕”이라는 문구와 함께 딸 이재아의 사진을 게재했다. 사진에는 이재아가 다리에 보조기를 차고 목발을 짚고 있는 모습이 그려졌다...  ', 'company': '뉴스엔', 'today': ' 2023.11.21 ', 'href': 'http://v.daum.net/v/20231121130400986'}

# %%
import pandas as pd

news_df = pd.DataFrame(mainList)

news_df

news_df.to_csv('news.csv')

# %%
print(news_df['company'] == "동아일보")
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# Name: company, dtype: bool

# %%
# 제목 : 
# 토마토 : 
# 팝콘 :
# 날짜 : 

import requests
from bs4 import BeautifulSoup
import pandas as pd
#select = "안녕" #input("제목을 작성하시오 : ")

url = f"https://www.rottentomatoes.com/browse/movies_at_home/sort:popular"

res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')

list_path = "#main-page-content > div.discovery > div.discovery-grids-container > div > div > div"
title_path = "tile-dynamic > a > span.p--small"
tomato_path = "div > div > span.percentage"
popcon_path = "div > div > span.percentage"
streaming_day_path = "tile-dynamic > a > span.smaller"

list_path = "div.flex-container"

list_up = soup.select(list_path)

movie_list = []

for item in list_up:
    
    # strip 여백 없애주는
    title = item.select('.p--small')[0].text.strip()
    streaming_day = item.select('.smaller')[0].text.strip()
    audiencescore = item.select('a')[0].select('score-pairs-deprecated')[0]['audiencescore']
    criticsscore = item.select('a')[0].select('score-pairs-deprecated')[0]['criticsscore']
    
    movie_list.append({"title" : title, "audiencescore" : audiencescore , "criticsscore" : criticsscore , "streaming_day" : streaming_day})
    
news_df = pd.DataFrame(movie_list)
news_df

#main-page-content > div.discovery > div.discovery-grids-container > div > div
#len(soup.select(list_path)
# Out:
#                                                 title audiencescore  \
# 0                                         Oppenheimer            91
# 1                                                 Leo            94
# 2                                       The Holdovers            90
# 3                                          The Killer            59
# 4                          Stamped From the Beginning            69
# 5                             Five Nights at Freddy's            87
# 6                                       Good Burger 2            73
# 7                                        Mister Organ            92
# 8                                         The Creator            76
# 9                                        May December            94
# 10                                    When Evil Lurks            81
# 11                                        Blue Beetle            91
# 12                          The Marsh King's Daughter            74
# 13                                              Genie            67
# 14                                           Mad Cats            82
# 15  Please Don't Destroy: The Treasure of Foggy Mo...            94
# 16                               A Haunting in Venice            77
# 17                                      Bye Bye Barry            98
# 18                             Best. Christmas. Ever!            19
# 19                                         Dumb Money            85
# 20                                   No Hard Feelings            87
# 21                                             Barbie            83
# 22                                    Blow Up My Life            80
# 23                                     Do Not Disturb            80
# 24                                         Talk to Me            82
# 25                                   The Hunger Games            81
# 26                               Frybread Face and Me            85
# 27                                         Past Lives            92
#
#    criticsscore           streaming_day
# 0            93  Streaming Nov 21, 2023
# 1            81  Streaming Nov 21, 2023
# 2            96  Streaming Nov 28, 2023
# 3            85  Streaming Nov 10, 2023
# 4           100  Streaming Nov 20, 2023
# 5            30  Streaming Oct 27, 2023
# 6            58  Streaming Nov 22, 2023
# 7            95  Streaming Nov 21, 2023
# 8            66  Streaming Nov 14, 2023
# 9            92   Streaming Dec 1, 2023
# 10           99  Streaming Oct 27, 2023
# 11           78  Streaming Sep 26, 2023
# 12           38  Streaming Nov 21, 2023
# 13           29  Streaming Nov 22, 2023
# 14          100  Streaming Nov 21, 2023
# 15           41  Streaming Nov 17, 2023
# 16           75  Streaming Oct 31, 2023
# 17           86  Streaming Nov 21, 2023
# 18           39  Streaming Nov 16, 2023
# 19           84   Streaming Nov 7, 2023
# 20           71  Streaming Aug 15, 2023
# 21           88  Streaming Sep 12, 2023
# 22           80  Streaming Nov 21, 2023
# 23           88  Streaming Nov 21, 2023
# 24           94  Streaming Sep 12, 2023
# 25           84   Streaming Sep 9, 2016
# 26          100  Streaming Nov 24, 2023
# 27           97  Streaming Aug 22, 2023

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
#select = "안녕" #input("제목을 작성하시오 : ")

url = f"https://www.rottentomatoes.com/browse/movies_at_home/sort:popular"

res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')

list_path = "div.flex-container"

list_up = soup.select(list_path)

movie_list = []

for item in list_up:
    title = item.select('.p--small')[0].text.strip()
    streaming_day = item.select('.smaller')[0].text.strip()
    audiencescore = item.select('a')[0].select('score-pairs-deprecated')[0]['audiencescore']
    criticsscore = item.select('a')[0].select('score-pairs-deprecated')[0]['criticsscore']
    
    movie_list.append({"title" : title, "audiencescore" : audiencescore , "criticsscore" : criticsscore , "streaming_day" : streaming_day})
    
movies_df = pd.DataFrame(movie_list)

movies_df

movies_df.to_csv("movies.csv")

# %%
# 네이트 검색 결과 뉴스페이지에서 검색어 결과 10 페이지까지 크롤링 해서 csv file로 저장하시오
import requests
from bs4 import BeautifulSoup
import pandas as pd

select = "안녕"

resultList = []

for i in range(1,11):
    
    url = f"https://search.daum.net/nate?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q={select}&p={i}"
    res = requests.get(url)

    soup = BeautifulSoup(res.text,'html.parser')

    main_path = '#dnsColl > div > ul > li'

    list_path = "#dnsColl > div:nth-child(1) > ul > li"

    company_path = "div.c-tit-doc > div.area_tit > div > a > strong > span"
    title_path = "div.item-title"

    contents_path = "div.item-contents > p"
    content_href_path = "div.item-title > strong > a"
    today_path = "div.c-item-content > div.item-bundle-mid > div.item-contents > span"
    
    soup.select(main_path)

    for i, item in enumerate(soup.select(main_path)):
        company = item.select(company_path)
        title = item.select(title_path)
        summary = item.select(contents_path)
        today = item.select(today_path)
        content_href = item.select(content_href_path)
    
        resultList.append({"title" : title[0].text, "summary" : summary[0].text, "company" : company[0].text, "today" : today[0].text, "href" : content_href[0]['href']})
    
for item in resultList:
    print(item)

result_df = pd.DataFrame(resultList)

result_df.to_csv("NateResult.csv")

result_df
# Out:
# {'title': "   얼굴 없는 노래방차트 1위 가수 #안녕, 알고보니 '연봉 1억' 받는 대기업 직원   ", 'summary': "  기자] 요즘 10대-20대에게 ’얼굴이 없어도‘ 아주 유명한 가수가 있다. 얼굴 없이 7년간 활동했던 가수 #안녕. '안녕'이라고 읽어야 하나, '샵안녕'이라고 읽어야 하나 모를 정도로 일반인들에게 익숙하지 않은 이름이지만 10대 20대 젊은 층이 애용하는 코노(코인...  ", 'company': 'OSEN', 'today': ' 2023.11.07 ', 'href': 'http://v.daum.net/v/20231107093520126'}
# {'title': '   "바가지요금 안녕"… 외국인 관광객용 택시 호출 앱 출시   ', 'summary': "  외국인 관광객 전용 택시 호출 앱 '타바'. 서울시 제공 #최근 서울을 방문한 중동 국가 출신 A씨는 성동구 왕십리에 가려다 거리에서 한참을 헤맸다. ‘왕십리’ 발음에 따른 영어 표기가 헷갈려서 지도 애플리케이션(앱)에서 목적지 가는 방법을 검색할 수가 없었기...  ", 'company': '한국일보', 'today': ' 57분전 ', 'href': 'http://v.daum.net/v/20231204132615538'}
# {'title': '   “웃으며 춤추듯 운동하니 관절통증도 우울증도 안녕”   ', 'summary': '  1일 경북 구미 새마을운동테마공원 부속동에서 열린 ‘어르신 체육활동’ 참가자들이 노래에 맞춰 생활체조를 하고 있는 모습. 아침 최저기온 영하 3도 체감기온은 영하 6도까지 떨어진 지난 1일, 경북 구미 사곡동 산자락에 자리 잡은 새마을운동테마공원은 금오산...  ', 'company': '서울신문', 'today': ' 2시간전 ', 'href': 'http://v.daum.net/v/20231204120201902'}
# {'title': '   [단독] 우울증에 신음하는 농어촌… 진료받을 정신과가 없어요 [대한민국 정신건강리포트-당신의 마음은 안녕하십니까<2>]   ', 'summary': '  인구 대비 정신과 치료를 받은 사람 수가 많은 지역 상위 50곳 중 20곳이 인구 5만명 미만의 농어촌 지역인 것으로 확인됐다. 반면 정신과 진료와 치료를 받을 수 있는 의료기관은 서울 등 대도시에 집중됐다. 그 결과 정신질환 치료 인프라가 부족한 강원 고성의...  ', 'company': '서울신문', 'today': ' 9시간전 탐사뉴스 ', 'href': 'http://v.daum.net/v/20231204050104496'}
# {'title': "   여의도순복음교회 신도 5000명, 영화 '안녕하세요' 단체관람   ", 'summary': "  [서울=뉴시스] 지난 11월29일 서울 영등포구 여의도CGV에서 진행된 영화 '안녕하세요' 여의도순복음교회 단체관람에 참여한 이영훈 목사(오른쪽) (사진=여의도순복음교회 제공) 2023.12.03. photo@newsis.com *재판매 및 DB 금지 [서울=뉴시스] 이수지 기자 = 여의도...  ", 'company': '뉴시스', 'today': ' 2023.12.03 ', 'href': 'http://v.daum.net/v/20231203092812554'}
# {'title': "   기온 오르며 당분간 '추위 안녕'…구름은 많은 편 [날씨]   ", 'summary': '  기사와 관련 없는 자료 사진. 경기일보DB 월요일인 4일부터 수도권 전지역이 대체로 흐려지지만, 기온은 오름세를 보여 당분간 추위 걱정은 없는 날씨가 이어진다. 수도권기상청에 따르면 이날 수도권의 최저 기온은 영하 7도에서 0도, 최고 기온은 영상 6도에서 9도...  ', 'company': '경기일보', 'today': ' 9시간전 ', 'href': 'http://v.daum.net/v/20231204050123523'}
# {'title': '   [경남 주말&문화] 당신의 안녕을 염원하며…‘무수히 안녕’   ', 'summary': "  [KBS 창원] [앵커] 경남 주말엔문화, 경남도립미술관이 올해 마지막 기획전, '무수히 안녕'을 내일(24일) 개막합니다. 모두의 '안녕'을 바라는 오랜 마음과 행위에 숨겨진 다양한 가치를 만나 보시죠. 진정은 기자입니다. [리포트] 불상과 나란히 등을 마주한 천사와...  ", 'company': 'KBS', 'today': ' 2023.11.23 ', 'href': 'http://v.daum.net/v/20231123220237776'}
# {'title': "   경남도립미술관 올해 마지막 기획전 '무수히 안녕' 24일 개막   ", 'summary': "  [창원=뉴시스] 경남도립미술관 2023년 마지막 기획전 '무수히 안녕' 포스터.(사진=경남도립미술관 제공0 2023.11.17. photo@newsis.com [창원=뉴시스] 홍정명 기자 = 경남도립미술관은 2023년 마지막 기획전 '무수히 안녕'을 오는 24일 개막한다. 무수히 안녕은 누군...  ", 'company': '뉴시스', 'today': ' 2023.11.17 ', 'href': 'http://v.daum.net/v/20231117101310381'}
# {'title': "   '복면가왕' 미다스의 손, 유리아·#안녕·효진·건지 꺾고 '가왕' 방어 [종합]   ", 'summary': '  베스트셀러가 \'사계\', 잘 찍어가 \'하루\'를 선곡해 맞대결을 펼쳤다. 결과는 베스트셀러의 승리였고, 잘 찍어 정체는 #안녕이었다. #안녕은 데뷔 이후 최초로 얼굴을 공개했다며 "반도체 기업에서 엔지니어로 근무 중인 회사원이다. 연차를 내고 녹화에 왔다"라고 말...  ', 'company': '티브이데일리', 'today': ' 2023.11.26 ', 'href': 'http://v.daum.net/v/20231126211607857'}
# {'title': '   이청아 "\'연인\' 각화, 만나기 어려운 캐릭터"...출연 비하인드 (\'안녕하니\')   ', 'summary': "  채널 딩고(dingo)는 지난 22일 오후 8시 딩고 뮤직 공식 유튜브 채널을 통해 힐링 뮤직 토크쇼 '너의 밤은 안녕하니' 2화를 공개했다. '너의 밤은 안녕하니'는 고요한 밤에 듣는 라디오를 연상시키는, 따뜻하고 편안한 분위기 속에 진행되는 뮤직 토크쇼 프로그램...  ", 'company': 'OSEN', 'today': ' 2023.11.23 ', 'href': 'http://v.daum.net/v/20231123113322502'}
# {'title': '   ‘안녕, 안녕! 안녕?’ 이시·제니박·심으뜸·김수지·김영석 단체전   ', 'summary': '  안녕?’을 주제로 열리고 있는 이번 단체전은 청년 작가들의 작업을 통해 미래의 청년, 과거의 청년, 그리고 현재의 청년에게 안녕을 묻고자 기획됐다. ⓒ올리비아박 갤러리 ⓒ올리비아박 갤러리 전시를 통해 희망을 담고 긍정적인 메세지를 담은 작품들을 마주함...  ', 'company': '프레시안', 'today': ' 2023.11.13 ', 'href': 'http://v.daum.net/v/20231113123103412'}
# {'title': '   안산 청년들, 안녕한가요?   ', 'summary': "  안산시지속가능발전협의회, 경기내일스퀘어안산 상상대로는 지난 18일 스페이스 오즈에서 2030안산청년들 공론장 '안산청년들 안녕한가요? : 누구도 배제되지 않는 청년들의 안정과 안전을 말하다'를 개최했다. 토론회 사회를 맡은 임윤희 평등평화세상온다 사무국장...  ", 'company': '오마이뉴스', 'today': ' 2023.11.21 ', 'href': 'http://v.daum.net/v/20231121134206808'}
# {'title': '   “안녕 내사랑, 내일까지”…부인 마지막 배웅한 99세 카터   ', 'summary': '  빠집니다”라고 말했다. 이어 “이것이 당신에게는 이상할까요? 제겐 전혀 그렇지 않습니다”라고 고백했다. 이어 편지 말미에 “안녕 내사랑, 내일까지. 지미가”라고 적었다. 로절린 카터 여사의 추도식에서 카터 전 대통령 장남 칩 카터에 부친의 이마에 입맞춤...  ', 'company': '국민일보', 'today': ' 2023.11.29 ', 'href': 'http://v.daum.net/v/20231129111005989'}
# {'title': '   ‘복면가왕’ ‘미다스의 손’, 1표차 승리하며 211대 가왕 등극...건지-효진-#안녕-유리아 정체 공개 [종합]   ', 'summary': '  사로잡았다. 대결의 승자는 ‘베스트셀러’였다. 이에 ‘모르는 건 잘 찍어’는 가면을 벗고 정체를 공개했는데 그는 #안녕이었다. #안녕은 “지금 회사원이다. 반도체 기업에서 엔지니어로 근무 중인데 연차 내고 왔다"고 하며 ”회식 때 노래방을 안 가려고 하는데...  ', 'company': 'MBC연예', 'today': ' 2023.11.26 ', 'href': 'http://v.daum.net/v/20231126195600335'}
# {'title': '   규현, 흉기 난동에 부상→김혜수 ‘청룡’과 뜨거운 안녕 [이슈박스]   ', 'summary': '  하는 영상 등이 유출돼 사생활 논란에 휩싸인 바 있다. 사진=서병수 기자 qudtn@edaily.co.kr ◇김혜수 ‘청룡영화상’과 뜨거운 안녕배우 김혜수가 ‘청룡영화상’과 30년 인연을 마무리했다.‘제44회 청룡영화상’이 지난 24일 오후 서울시 영등포구 KBS홀에서...  ', 'company': '일간스포츠', 'today': ' 2023.11.25 ', 'href': 'http://v.daum.net/v/20231125103039202'}
# {'title': '   “기후위기 시대, 당신의 계절은 안녕한가요?”   ', 'summary': '  잇따른 수상으로 기후위기 시대 로드맵을 제시하고 나섰습니다. 제주CBS가 제작한 특집 다큐멘터리 ‘기후역습-제주의 봄가을은 안녕하십니까’가 방송문화진흥회 지역프로그램상을 수상했습니다. 방송문화진흥회는 오늘(23일) 한국프레스센터 18층 서울클럽홀에서...  ', 'company': 'JIBS', 'today': ' 2023.11.23 ', 'href': 'http://v.daum.net/v/20231123153541269'}
# {'title': '   로코베리 로코, 배우 박신혜와 절친 케미···토크쇼 ‘너의 밤은 안녕하니?’ 첫 회부터 100만뷰 돌파   ', 'summary': '  딩고뮤직 ‘너의 밤은 안녕하니?’ 영상 캡처 히트 작곡팀이자 밴드 로코베리의 로코가 색다른 뮤직 토크쇼 ‘너의 밤은 안녕하니?’로 시청자들을 사로잡았다.지난 8일 디지털 미디어 채널 딩고뮤직 공식 유튜브 채널을 통해 로코가 진행하는 신규 뮤직 토크쇼 ‘너...  ', 'company': '스포츠경향', 'today': ' 2023.11.14 ', 'href': 'http://v.daum.net/v/20231114221625760'}
# {'title': '   이청아 "작품이 사랑받는 것=큰 복" 솔직 입담(너의 밤은 안녕하니)   ', 'summary': "  채널 딩고(dingo)는 지난 22일 오후 8시 딩고 뮤직 공식 유튜브 채널을 통해 힐링 뮤직 토크쇼 '너의 밤은 안녕하니' 2화를 공개했다. '너의 밤은 안녕하니'는 고요한 밤에 듣는 라디오를 연상시키는, 따뜻하고 편안한 분위기 속에 진행되는 뮤직 토크쇼 프로그램...  ", 'company': 'MBC연예', 'today': ' 2023.11.23 ', 'href': 'http://v.daum.net/v/20231123103107515'}
# {'title': '   케이브이알인터랙티브, 추모 플랫폼 ‘안녕’ 서비스 개시   ', 'summary': '  케이브이알인터랙티브는 △메타버스 추모공간에서 고인을 추억하는 추모별 △고인과의 가상재회를 제공하는 추모플랫폼-안녕 서비스를 시작한다고 밝혔다. 글로벌 시대에 살고 있는 우리는 세계 각지에 사는 고인의 가족, 지인이 직접 장례식에 참석하거나 묘지를...  ', 'company': '아시아경제', 'today': ' 2023.11.21 ', 'href': 'http://v.daum.net/v/20231121104508362'}
# {'title': '   시그니처(Cignature), ‘안녕, 인사해’ 무대 직캠 (2023 서울 석세스 대상) [SS쇼캠]   ', 'summary': '  주최하고 굿모닝경제, 스포츠서울, 서울STV, 스포츠서울 Ent TV가 주관하며 정치부문, 경제부문, 사회부문, 문화부문 등으로 나뉘어 진행됐다. 시그니처(Cignature), ‘안녕, 인사해’ 무대 직캠 (2023 서울 석세스 대상) park5544@sportsseoul.com 사진 | 유튜브  ', 'company': '스포츠서울', 'today': ' 2023.11.21 ', 'href': 'http://v.daum.net/v/20231121093317548'}
# {'title': '   [단독] 가까운 정신과는 3시간, 가족에겐 말 못 해… 때 놓쳐 깊어진 우울증 [대한민국 정신건강리포트-당신의 마음은 안녕하십니까]   ', 'summary': '  <2회> 없는 것이 아니다 쳐다보지 않았을 뿐 도농 정신질환 병원 2.5배 차접근성 열악해 치료 적기 놓쳐시골, 이웃끼리 잘 알아 불편자식에게 부담 줄까 봐 숨겨정신과 보호병동 갈수록 줄어강원, 전공의 정원 없어 운영난 #강원 양구군에 사는 70대 할아버지 A씨는...  ', 'company': '서울신문', 'today': ' 19시간전 탐사뉴스 ', 'href': 'http://v.daum.net/v/20231203190003345'}
# {'title': '   카터 "안녕 내 사랑…" 로절린 여사 마지막 길 배웅   ', 'summary': '  카터는 카터 전 대통령이 신혼 시절 작성한 편지도 공개했다. 카터 전 대통령은 "당신을 볼 때마다 나는 다시 사랑에 빠진다"며 "안녕 당신. 내일까지"라고 덧붙였다. 이날 추도식에는 조 바이든 대통령 부부를 비롯해 전·현직 영부인 다섯 명이 모두 참석했다...  ', 'company': '매일경제', 'today': ' 2023.11.29 ', 'href': 'http://v.daum.net/v/20231129170607423'}
# {'title': '   얼굴 없는 가수 #안녕, 연봉 1억 받는 대기업 직원…오늘 신곡 공개   ', 'summary': "  10~20대에게 얼굴 없는 가수로 알려진 #안녕의 정체가 밝혀졌습니다. '안녕'이라고 읽어야 하나, '샵안녕'이라고 읽어야 하나 모를 정도로 일반인들에게 익숙하지 않은 이름이지만, #안녕은 10~20대 젊은 층이 애용하는 코노(코인 노래방) 차트에서는 이름이 빠지지...  ", 'company': 'MBN', 'today': ' 2023.11.07 ', 'href': 'http://v.daum.net/v/20231107155738201'}
# {'title': '   "안녕, 청룡" 김혜수, 마지막 MC[★화보]   ', 'summary': '  [스타뉴스 | 김창현 기자] "안녕, 청룡" 김혜수, 마지막 MC[★화보] 배우 김혜수가 24일 오후 서울 영등포구 여의도동 KBS 신관홀에서 진행된 \'제44회 청룡영화상\' 레드카펫 행사에 참석해 포즈를 취하고 있다. 2023.11.24 "안녕, 청룡" 김혜수, 마지막 MC[★화보...  ', 'company': '스타뉴스', 'today': ' 2023.11.24 ', 'href': 'http://v.daum.net/v/20231124204653508'}
# {'title': '   ‘현역가왕’ 대성 “안녕하세요 대성입니다~~” 미친 텐션   ', 'summary': '  했었다”고 언급하자, 순간 ‘날 봐 귀순’ 음악이 흘러나왔고, 대성은 지체없이 자리에서 일어나 바로 마이크를 쥐더니 “안녕하세요 대성입니다~~”를 맛깔나는 행사 톤으로 외쳐 폭소를 선사했다. 급기야 대성은 무대 앞으로 뛰어나가 특유의 폭풍 성량을 바탕...  ', 'company': '스포츠경향', 'today': ' 2023.11.20 ', 'href': 'http://v.daum.net/v/20231120213504793'}
# {'title': '   “안녕하세요, 이재용입니다!”…사칭 계정에 속지 마세요   ', 'summary': '  유명인을 사칭한 리딩방 광고가 끊이지 않고 있다. 이재용 삼성전자 회장을 사칭한 ‘이재용’ 계정이 올린 페이스북 광고는 “안녕하세요. 이재용입니다!”라며 “당신이 직장인이라도 월 1200만원의 배당금을 손 쉽게 벌고 1억원의 부를 축적할 수 있다”라며 주식...  ', 'company': '서울신문', 'today': ' 2023.11.07 ', 'href': 'http://v.daum.net/v/20231107104802320'}
# {'title': '   \'이동국 딸\' 재아, 세 번의 수술 후 근황 "영원히 안녕"   ', 'summary': '  뉴스 윤현지 기자) 전 축구선수 이동국의 딸 이재아의 근황이 공개됐다. 지난 15일 이동국의 아내 이수진은 "목발 보조기 영원히 안녕"이라는 글과 함께 딸 재아의 사진을 올렸다. 사진 속 재아는 다리에 보조기를 차고 목발을 짚고 있다. 한편 이재아는 지난해 12월...  ', 'company': '엑스포츠뉴스', 'today': ' 2023.11.17 ', 'href': 'http://v.daum.net/v/20231117194002988'}
# {'title': '   박신혜 ‘너의 밤은 안녕하니’ 첫 게스트 출격, 로코와 16년 절친   ', 'summary': "  딩고 딩고 [뉴스엔 하지원 기자] 디지털 미디어 채널 딩고(dingo)가 신규 예능 프로그램 '너의 밤은 안녕하니'를 선보인다. 딩고는 힐링 뮤직 토크쇼 '너의 밤은 안녕하니'는 11월 8일 오후 8시 딩고 뮤직 공식 유튜브 채널을 통해 첫 공개된다. '너의 밤은 안녕하니...  ", 'company': '뉴스엔', 'today': ' 2023.11.08 ', 'href': 'http://v.daum.net/v/20231108095000135'}
# {'title': '   “안녕 내 사랑, 내일까지” 77년 해로 카터의 마지막 인사   ', 'summary': '  볼 때마다 나는 다시 사랑에 빠진다”며 “이것이 당신에게는 이상할까요. 나에게는 그렇지 않습니다”라고 적었다. 그는 이어 “안녕 당신. 내일까지”라고 덧붙였다. 이날 추도식에는 조 바이든 대통령 부부를 비롯해 전현직 영부인 다섯 명이 모두 참석했다...  ', 'company': '매일경제', 'today': ' 2023.11.29 ', 'href': 'http://v.daum.net/v/20231129095401397'}
# {'title': '   이유미 “강남순, 즐겁고 행복했다…안녕”   ', 'summary': '  드렸다면 그걸로 저에겐 충분하다”며 “감독님과 작가님, 모든 순간 함께했던 배우, 스태프분들 그리고 많은 사랑 주신 시청자분들까지 감사하고 사랑한다. 강남순이어서 즐겁고 행복했다. 안녕”이라고 감사 인사를 전했다.김지우 온라인기자 zwoome@kyunghyang.com  ', 'company': '스포츠경향', 'today': ' 2023.11.27 ', 'href': 'http://v.daum.net/v/20231127111153267'}
# {'title': '   "안녕하세요 유재석입니다" 사칭광고 \'방치\'하는 페이스북   ', 'summary': "  모니터 결과 유재석, 현정은, 이부진, 주진형, 황현희 등 사칭 광고가 페이스북에 게재됐다. '유재석 KR'이라는 이름의 계정은 “안녕하세요 여러분. 제 이름은 유재석입니다”라며 “좋건 싫건 자본주의 하에서 살아갈 수밖에 없는 우리에게 금융 공부는 선택이...  ", 'company': '미디어오늘', 'today': ' 2023.11.06 ', 'href': 'http://v.daum.net/v/20231106114948597'}
# {'title': "   이근호 '안녕'   ", 'summary': "  (대구=뉴스1) 공정식 기자 = 3일 오후 대구 북구 DGB대구은행파크에서 열린 프로축구 '2023 하나원큐 K리그1' 38라운드 대구FC와 인천Utd의 시즌 마지막 경기, 이 경기를 끝으로 은퇴하는 대구 이근호가 후반전 교체되며 동료들과 인사 나누고 있다. 2023.12.3/뉴스1...  ", 'company': '뉴스1', 'today': ' 22시간전 ', 'href': 'http://v.daum.net/v/20231203153927589'}
# {'title': "   등굣길 4년째 '안녕하세요' 인사하는 할머니를 아시나요?   ", 'summary': '  4년째 북구시니어클럽 일자리사업으로 아이들의 등굣길 교통안전을 책임지고 있는 강찬순(72) 할머니. 북구청 제공 "안녕하세요. 그래 학교 잘 다녀와." 울산 북구 강동초등학교와 강동고등학교 등굣길에서 매일 아침 아이들에게 \'안녕하세요\' 인사를 하며 교통지도...  ', 'company': '노컷뉴스', 'today': ' 2023.11.15 ', 'href': 'http://v.daum.net/v/20231115114201933'}
# {'title': "   김남길, 어르신 주거 안전 캠페인 '밤새 안녕하셨어요' 크라우드 펀딩   ", 'summary': "  영향력을 이어간다. 문화예술NGO '길스토리(대표 김남길)'가 의료취약지역 어르신들의 안전한 주거 환경 조성을 위한 캠페인 '밤새 안녕하셨어요' 크라우드 펀딩을 시작했다. 어르신 주거 안전 캠페인 '밤새 안녕하셨어요'는 의료취약지역 어르신들의 집안 환경 개선...  ", 'company': 'JTBC', 'today': ' 2023.11.08 ', 'href': 'http://v.daum.net/v/20231108111942525'}
# {'title': '   우울증 환자 100만명 시대… 중증도 30만명 넘어[당신의 마음은 안녕하십니까]   ', 'summary': '  통상 ‘마음의 감기’로 불리는 우울증으로 진료받는 환자의 수가 2022년 100만명을 넘은 것으로 나타났다. 중증 우울증 환자 수는 30만명을 넘었다. ‘감기’라는 단어에는 누구나 걸릴 수 있고 치료를 통해 나을 수 있다는 인식이 담겨 있으나 가볍게 볼 수만은...  ', 'company': '서울신문', 'today': ' 2023.11.30 탐사뉴스 ', 'href': 'http://v.daum.net/v/20231130050119551'}
# {'title': "   에드가 '안녕하세요?'   ", 'summary': "  (대구=뉴스1) 공정식 기자 = 3일 오후 대구 북구 DGB대구은행파크에서 열린 프로축구 '2023 하나원큐 K리그1' 38라운드 대구FC와 인천Utd의 시즌 마지막 경기, 전반전 대구 에드가가 공격하고 있다. 2023.12.3/뉴스1 jsgong@news1.kr  ", 'company': '뉴스1', 'today': ' 23시간전 ', 'href': 'http://v.daum.net/v/20231203151610120'}
# {'title': '   카라 규리, 故 구하라 향한 그리움..."안녕"   ', 'summary': '  구하라의 4주기를 추모했다. 24일 규리는 자신의 소셜네트워크서비스에 구하라의 생전 모습이 담긴 포스터 사진을 올렸다. 그는 "안녕"이라고 짧게 덧붙였다. 포스터에는 구하라의 사진과 함께 \'당신의 미소는 언제나 우리들의 마음 속에\'라는 문구가 적혀있다. 지난...  ', 'company': 'TV리포트', 'today': ' 2023.11.24 ', 'href': 'http://v.daum.net/v/20231124190200706'}
# {'title': "   박신혜, 딩고 신규 예능 콘텐츠 '너의 밤은 안녕하니' 첫 게스트   ", 'summary': "  뉴스 | 김수진 기자] 박신혜(왼쪽)와 로코 / 사진제공=딩고 배우 박신혜가 딩고(dingo)가 론칭한 신규 예능 프로그램 '너의 밤은 안녕하니'에 출연한다. 딩고에 따르면 8일 오후 8시 힐링 뮤직 토크쇼 '너의 밤은 안녕하니' 첫회가 공개된다. '너의 밤은 안녕하니'는...  ", 'company': '스타뉴스', 'today': ' 2023.11.08 ', 'href': 'http://v.daum.net/v/20231108131337602'}
# {'title': '   [세종로의 아침] 당신은 안녕한가요/이현정 세종취재본부 차장   ', 'summary': '  이현정 세종취재본부 차장 그때는 아침이 죽음과 함께 왔다. 절망이 야금야금 밤을 갉아먹어 약 없이는 잠들지 못했고, 일상은 무너졌으며 아침은 두려운 것이 됐다. 새로 떠오르는 해가 아직 동트기 전의 새벽에 갇히길, 이대로 오늘이 어제의 시간에 박제되길...  ', 'company': '서울신문', 'today': ' 2023.12.01 ', 'href': 'http://v.daum.net/v/20231201050354495'}
# {'title': '   화 참다 공황장애, 결혼 반대에 우울증… 평범한 일상, 병이 됐죠[당신의 마음은 안녕하십니까]   ', 'summary': '  서울신문은 우리 주변에 가려진 정신질환자 8명을 직접 만나 이들의 마음속 이야기를 들었다. 어떻게 정신질환을 얻게 됐는지, 정신질환 진단과 치료 전후로 삶이 어떻게 달라졌는지를 물었다. 8명 모두 자신의 병을 알게 된 뒤 이를 이겨 내기 위해 고통을 감내하며...  ', 'company': '서울신문', 'today': ' 2023.11.30 탐사뉴스 ', 'href': 'http://v.daum.net/v/20231130050121553'}
# {'title': '   [강원도민 여러분 밤새 안녕하셨습니까] ③ 지역별 의료 수요 감당 못하는 강원도   ', 'summary': '  강원 의료 인프라의 가장 큰 문제는 지역의 수요를 맞추지 못한다는 점이다. 군(郡) 단위 외 다른 지역 역시 환자 비율과 보유하고 있는 의료인력의 격차가 상당하다. 29일 강원도민일보와 강원특별자치도공공보건의료지원단이 건강보험심사평가원의 지자체별 맞춤형...  ', 'company': '강원도민일보', 'today': ' 2023.11.30 ', 'href': 'http://v.daum.net/v/20231130000609380'}
# {'title': "   영도 어린이에게 '안녕' 전하는 프로젝트 전시 '노랑안녕' 개최   ", 'summary': "  [부산=뉴시스] 프로젝트 전시 '노란안녕' 메인 포스터. (사진=영도문화도시센터 제공) *재판매 및 DB 금지 [부산=뉴시스]권태완 기자 = 영도문화도시센터는 오는 13일부터 다음달 3일까지 3주간 홍매실 해피하우스에서 영도 어린이들에게 안녕을 전하는 프로젝트...  ", 'company': '뉴시스', 'today': ' 2023.11.11 ', 'href': 'http://v.daum.net/v/20231111071808663'}
# {'title': "   '상봉터미널, 안녕? 안녕…'   ", 'summary': '  29일 폐업을 앞둔 서울 중랑구 상봉터미널의 모습. 1985년 문을 연 상봉터미널은 오는 30일 영업을 끝으로 운영을 종료한다. 상봉터미널은 한때 이용객이 하루 평균 2만명을 넘어서는 등 서울 지역 내 주요 터미널로 자리를 잡았으나, 1990년 동서울터미널이 완공...  ', 'company': '노컷뉴스', 'today': ' 2023.11.29 ', 'href': 'http://v.daum.net/v/20231129125704232'}
# {'title': '   ‘이동국 딸’ 이재아, 테니스선수 은퇴 후 근황 “목발 영원히 안녕”   ', 'summary': '  둘째 딸 이재아의 근황이 공개됐다. 지난 15일 이동국의 아내 이수진은 자신의 소셜네트워크서비스 계정에 “목발 보조기 영원히 안녕”이라는 문구와 함께 딸 이재아의 사진을 게재했다. 사진에는 이재아가 다리에 보조기를 차고 목발을 짚고 있는 모습이 그려졌다...  ', 'company': '뉴스엔', 'today': ' 2023.11.21 ', 'href': 'http://v.daum.net/v/20231121130400986'}
# {'title': '   [우애리의 ‘마음아 안녕’(55)] 우리아이의 첫 친구‘ 애착 인형’   ', 'summary': '  6개월~12개월 영유아기는 강력한 애착 관계 형성이 일어나는 시기이다. 이때 아이들은 가장 가까운 보호자와와 안정적인 관계를 통해 세상을 탐색하기 시작한다. ‘애착 인형’은 이 시기 아이들이 자신의 정체감을 이해하고 안정감을 찾고, 세상을 안전하게 탐색할...  ', 'company': '데일리안', 'today': ' 2023.11.30 ', 'href': 'http://v.daum.net/v/20231130095837382'}
# {'title': '   [★타임머신]‘섹드립 일인자’ 알고 보니 원조 꽃미남 개그맨?... ‘술 잘 마시는 동물농장 아저씨’ 신동엽, n번째 전성기도 “안녕하시렵니까”   ', 'summary': '  훤칠한 외모와 능글대는 귀여움으로 별다른 무명 시절 없이 ‘토요일 7시 웃으면 좋아요’의 코너 ‘레일맨’에서 유행어 “안녕하시렵니까?”로 단숨에 스타가 되었다. 이어서 그는 예능프로 ‘기쁜 우리 토요일’ 시트콤 ‘남자 셋 여자 셋’으로 인기의 정점을...  ', 'company': '스포츠서울', 'today': ' 2023.11.20 ', 'href': 'http://v.daum.net/v/20231120060047215'}
# {'title': '   "이혼 안 해" ♥애정 과시한 유부 스타들…\'11월 괴담 안녕!\' [엑\'s 이슈]   ', 'summary': "  (엑스포츠뉴스 오승현 기자) 많은 스타들이 행복한 결혼 생활을 드러내 훈훈함을 자아냈다. 최근 많은 연예인들의 파경 소식이 전해지며 일명 '11월의 괴담'으로 시끄럽던 연예계다. 좋지 못한 소식으로 안타까움으로 물들었던 11월의 말, 다양한 스타들이 배우자...  ", 'company': '엑스포츠뉴스', 'today': ' 2023.11.29 ', 'href': 'http://v.daum.net/v/20231129081003072'}
# {'title': '   “안녕” 카라 박규리·니콜, 故 구하라 4주기에 전한 마음   ', 'summary': '  그리움을 드러냈다. 박규리는 24일 자신의 인스타그램에 팬들이 구하라를 추억하며 지하철 역에 건 광고판 사진을 게재하며 “안녕”이라는 인사를 전했다. 광고판에는 생전 구하라가 무대에서 퍼포먼스를 하는 모습이 담긴 사진과 함께 ‘당신의 미소는 언제나 우리...  ', 'company': 'OSEN', 'today': ' 2023.11.24 ', 'href': 'http://v.daum.net/v/20231124181402786'}
# {'title': '   에스파 윈터 ‘팬들 안녕~’   ', 'summary': '  2023 멜론 뮤직 어워드(MMA2023) 레드카펫이 2일 오후 인천 인스파이어 아레나에서 열렸다. 아이즈원 출신 혼다 히토미와 야부키 나코가 공동 MC로 나선 MMA2023은 화려한 라인업을 자랑한다. 에스파 윈터가 포토타임을 갖고 있다. 사진=천정환 기자 NCT DREAM...  ', 'company': 'MK스포츠', 'today': ' 2023.12.02 ', 'href': 'http://v.daum.net/v/20231202173004084'}
# {'title': "   [TD포토] 고민시 '안녕~'   ", 'summary': "  티브이데일리 포토 [티브이데일리 안성후 기자] 넷플릭스 '스위트홈' 시즌2 제작발표회가 30일 오전 서울 성동구 성수동 에스팩토리에서 열렸다. 이날 이응복 감독, 배우 송강, 이진욱, 이시영, 고민시, 진영, 유오성, 김무열 등이 참석해 자리를 빛냈다. 넷플릭스...  ", 'company': '티브이데일리', 'today': ' 2023.11.30 ', 'href': 'http://v.daum.net/v/20231130115007080'}
# {'title': '   "안녕하세요, 신입입니다. 71살이고요"   ', 'summary': '  클럽 제공 ▶ 글 싣는 순서 ①\'노인 지옥\' 죽거나 죽이거나…흉기로 변한 빈곤②평균 퇴직 49.4세…\'죽음의 계곡\' 떠밀리는 나라③"안녕하세요, 신입입니다. 71살이고요"(계속) 깨를 고온에서 볶으면 단백질과 지방이 분해되면서 발암물질인 벤조피렌이 나온다는...  ', 'company': '노컷뉴스', 'today': ' 2023.11.08 탐사뉴스 ', 'href': 'http://v.daum.net/v/20231108052100470'}
# {'title': "   [TD포토] 제로베이스원 장하오-한유진-석매튜 '안녕'   ", 'summary': '  티브이데일리 포토 [인천=티브이데일리 송선미 기자] 제로베이스원 장하오 한유진 석매튜가 2일 오후 인천광역시 중구 인스파이어 아레나에서 열린 MMA2023(멜론뮤직어워드) 레드카펫에 참석하고 있다. MMA2023(멜론뮤직어워드)에는 NCT DREAM(엔시티 드림) aespa...  ', 'company': '티브이데일리', 'today': ' 2023.12.02 ', 'href': 'http://v.daum.net/v/20231202180520832'}
# {'title': '   "안녕, 잘 있었어?"...이동건, 15년 전 세상 떠난 동생 36번째 생일 맞이   ', 'summary': '  성당에 방문하는 이동건의 모습이 담겼다. 이동건은 매년 동생의 생일마다 성당을 찾는다고. 그는 36번째 동생 생일을 축하하며 “안녕? 잘 있었어? 벌써 36번째 생일이야. 스무 살에 멈춰있는 네가 어른이 된 모습이 상상이 안 간다”고 말을 건넸다. 카드를 건넨...  ', 'company': '세계일보', 'today': ' 2023.12.03 ', 'href': 'http://v.daum.net/v/20231203113958499'}
# {'title': '   [강원도민 여러분 밤새 안녕하셨습니까] ② 질병이 두려운 군(郡) 주민들   ', 'summary': '  #정선에 거주하고 있는 김모(67)씨는 1년 전부터 연세대원주세브란스기독병원으로 고혈압, 당뇨 등 만성질환에 대한 외래진료를 다니고 있다. 한 달에 한 번 병원에 내원하고 있고 보통 자가용을 이용하는데 정선에서 원주로 가는 데만 약 1시간 30분 정도가 소요...  ', 'company': '강원도민일보', 'today': ' 2023.11.27 ', 'href': 'http://v.daum.net/v/20231127000546889'}
# {'title': '   한지완, 강율 이별 통보에 오열.."우혁아, 안녕"[우아한 제국][★밤TView]   ', 'summary': '  일 안 할거다"라며 이별을 통보했다. 정우혁은 \'그렇게 해라\'며 눈물을 흘리는 서희재에 "사랑했다. 이젠 내가 널 잊겠다"고 단호히 이야기했다. 이별을 통보받은 서희재는 병실 밖으로 나가 "우혁아. 안녕"이라며 눈물을 쏟아냈다. 김지은 기자 star@mtstarnews.com  ', 'company': '스타뉴스', 'today': ' 2023.11.14 ', 'href': 'http://v.daum.net/v/20231114204039614'}
# {'title': "   전다현 감독 '안녕, 우주' 부천국제애니메이션페스티벌 초청   ", 'summary': "  세종대 만화애니메이션텍전공 졸업생 전다현 감독의 단편 애니메이션 '안녕, 우주'가 지난달 20일 개막한 부천국제애니메이션페스티벌(BIAF)에서 국제경쟁 학생 단편 부문에 공식 초청됐다고 2일 밝혔다. (사진=세종대 제공) *재판매 및 DB 금지 [서울=뉴시스]이주영...  ", 'company': '뉴시스', 'today': ' 2023.11.02 ', 'href': 'http://v.daum.net/v/20231102163950183'}
# {'title': '   영월 봉래산 천제 봉행…군민 안녕·지역 발전 기원   ', 'summary': '  DB 금지] (영월=연합뉴스) 배연호 기자 = 강원 영월군이 10일 제45회 영월군 농업인의 날을 맞아 봉래산 정상에서 추수 감사, 군민 안녕, 지역 발전 등을 기원하는 천제를 봉행했다. 봉래산 천제 봉행은 영월군 농업인단체협의회 주관으로 2019년부터 시작됐다. 천제...  ', 'company': '연합뉴스', 'today': ' 2023.11.10 ', 'href': 'http://v.daum.net/v/20231110131602511'}
# {'title': '   "쌍용자동차 진짜 안녕"…KG 모빌리티, 신규 브랜드 \'KGM\' 론칭   ', 'summary': "  판매·서비스 네트워크 새 단장…브랜드 이미지 강화 쌍용자동차 35년 만에 역사의 뒤안길로 퇴장 KG 모빌리티가 출범 1주년을 맞아 새로운 신규 대표 브랜드 'KGM'을 선보인다. /KG 모빌리티 [더팩트 | 김태환 기자] KG 모빌리티가 KG 그룹 가족사 편입 1...  ", 'company': '더팩트', 'today': ' 2023.11.30 ', 'href': 'http://v.daum.net/v/20231130110112330'}
# {'title': '   ‘뜨거운 안녕’ 쟈니 리 “전쟁 고아였던 소년, 미군이 선뜻 거둬줘”   ', 'summary': '  큼직한 선글라스를 쓰고 약속 장소인 서울 종로의 라이브 바에 나타났다. 이곳에서 요즘도 노래를 한다고 했다. 1966년 ‘뜨거운 안녕’, ‘내일은 해가 뜬다’ 같은 히트곡을 발표한 지 60년이 돼 가는 지금도 여전한 가수의 풍모였다. 전쟁 고아였던 쟈니 리가...  ', 'company': '조선일보', 'today': ' 2023.11.04 탐사뉴스 ', 'href': 'http://v.daum.net/v/20231104041048780'}
# {'title': '   안녕 2023! 올해 마지막달 세계 경제에 ‘금리 인상’ 없을듯   ', 'summary': '  WEEKLY BIZ 뉴스레터 구독하기 ☞ https://page.stibee.com/subscriptions/146096 11월 8일 제롬 파월 미국 연방준비제도 의장. /AFP 연합뉴스 한국은행이 30일 기준금리를 연 3.5%로 동결했다. 2월 이후 7회 연속 동결 조치다. 한은뿐 아니라 주요국 중앙은행들이...  ', 'company': '조선일보', 'today': ' 2023.11.30 ', 'href': 'http://v.daum.net/v/20231130143136719'}
# {'title': "   샤이니 민호, '안녕' [사진]   ", 'summary': '  [OSEN=지형준 기자] 2일 오후 인천 인스파이어 아레나에서 멜론뮤직어워드(MMA2023) 레드카펫 행사가 열렸다. 가수 샤아니 민호가 포토타임을 하고 있다. 2023.12.02 / jpnews.osen.co.kr  ', 'company': 'OSEN', 'today': ' 2023.12.02 ', 'href': 'http://v.daum.net/v/20231202210920614'}
# {'title': '   “안녕? 청년밥차 민이라고 해” 개그맨 오지헌 대학교에 떴다[따만사]   ', 'summary': '  오 간사는 2003년 KBS 공채 18기에 합격해 개그맨의 길에 들어선 지 20년이 됐다. 데뷔하자마자 그는 KBS2 개그콘서트를 통해 “안녕~! 난 민이라고 해”라는 유행어를 만들어 내기도 했다. 그는 “다른 개그맨들보다 쉽게 개그맨이 됐고 쉽게 성공을 해버렸다. 물론...  ', 'company': '동아일보', 'today': ' 2023.11.24 탐사뉴스 ', 'href': 'http://v.daum.net/v/20231124140009057'}
# {'title': "   스튜디오니니, 웹툰 '수의사님!안녕하세요?' 한달만에 200만뷰 돌파   ", 'summary': "  스튜디오니니는 지난 9월 카카오페이지, 카카오웹툰에 런칭한 웹툰 '수의사님! 안녕하세요?'가 런칭 한 달만에 200만뷰를 돌파했다고 6일 밝혔다. 조회수의 빠른 상승세로 드라마 웹툰 장르로서는 드물게 웹툰 신작의 성공적인 출발을 보여주고 있다. 스튜디오니니의...  ", 'company': '전자신문', 'today': ' 2023.11.06 ', 'href': 'http://v.daum.net/v/20231106113903216'}
# {'title': "   인천 부평구문화재단, 포럼 '문화도시, 안녕하신가요?' 개최   ", 'summary': "  [인천=뉴시스] 이루비 기자 = 인천 부평구문화재단은 16일 오후 부평아트센터 세미나실에서 부평문화포럼 '문화도시, 안녕하신가요?'를 개최한다고 7일 밝혔다. 1회차 포럼의 부제는 '문화도시 진단과 대안 모색'이다. 이번 포럼은 문화체육관광부의 제5차 법정문화...  ", 'company': '뉴시스', 'today': ' 2023.11.07 ', 'href': 'http://v.daum.net/v/20231107132913341'}
# {'title': "   실리카겔, '안녕하세요' [사진]   ", 'summary': '  [OSEN=지형준 기자] 2일 오후 인천 인스파이어 아레나에서 멜론뮤직어워드(MMA2023) 레드카펫 행사가 열렸다. 실리카겔이 포토타임을 하고 있다. 2023.12.02 / jpnews.osen.co.kr  ', 'company': 'OSEN', 'today': ' 2023.12.02 ', 'href': 'http://v.daum.net/v/20231202181659992'}
# {'title': "   독립기념관, 장애학생 위한 '안녕, 독립기념관' 프로그램 개설   ", 'summary': "  제공. 재판매 및 DB 금지] (천안=연합뉴스) 유의주 기자 = 독립기념관은 9일 장애 학생의 독립운동사 교육 접근성 강화를 위해 '안녕, 독립기념관' 프로그램을 개설한다고 밝혔다. 교육은 크게 시각장애 학생 프로그램인 '우리의 태극기'와 발달장애 학생 대상의...  ", 'company': '연합뉴스', 'today': ' 2023.11.09 ', 'href': 'http://v.daum.net/v/20231109094201418'}
# {'title': "   '플라스틱이여 안녕~'…이상일 용인특례시장, '바이바이 플라스틱 챌린지' 참여   ", 'summary': '  이상일 시장이 지난 14일 시청 청사에서 ‘바이바이(bye bye) 플라스틱 챌린지’에 참여했다고 15일 밝혔다. 이 시장은 ‘플라스틱 안녕’이라는 제스처로 손을 흔드는 사진을 찍어 사회관계망서비스(SNS)에 올렸다. 플라스틱 사용을 최대한 줄이자는 범국민 실천...  ', 'company': '데일리안', 'today': ' 2023.11.15 ', 'href': 'http://v.daum.net/v/20231115122003176'}
# {'title': "   [녹색] 수입원료 '안녕'...우리 농산물 활용한 대체육 개발   ", 'summary': '  [앵커] 건강과 환경에 대한 소비자 관심 속에 대체식품 시장의 성장세가 이어지고 있는데요. 그동안 수입원료에 의존해왔지만, 국내 연구진이 우리 농산물을 활용해 새로운 대체식품 생산 방식을 개발하는 데 성공했습니다. 김민성 기자의 보도입니다. [기자...  ', 'company': 'YTN', 'today': ' 2023.11.30 ', 'href': 'http://v.daum.net/v/20231130184630215'}
# {'title': '   "18개월, 잠시 안녕"... 송강·세훈→BTS, \'군대\'가는 ★ [종합]   ', 'summary': "  [TV리포트=강성훈 기자] 잘나가는 남자 스타의 커리어에 있어 '국방의 의무'는 가장 큰 위기로 다가온다. 군대에 있는 '군백기' 동안 활동에 제한받기 때문이다. 이 가운데 월드클래스 보이그룹 방탄소년단 그리고 1994년생 스타들이 입대를 앞두고 있어 관심이...  ", 'company': 'TV리포트', 'today': ' 2023.11.23 ', 'href': 'http://v.daum.net/v/20231123183200357'}
# {'title': '   나는 [숨겨야만 사는] 정신질환자입니다[당신의 마음은 안녕하십니까]   ', 'summary': '  최서연(가명)씨는 27세 여성 요리사다. 어릴 때부터 정신과 치료를 받고 싶었지만 부모님의 반대로 성인이 돼서야 상담실 문을 두드렸다. 치료 전에는 자살도 여러 차례 시도했다. 지금은 삶에 대한 의지가 누구보다 더 강하다. 서울신문과 만나 자신을 괴롭혔던...  ', 'company': '서울신문', 'today': ' 2023.11.30 탐사뉴스 ', 'href': 'http://v.daum.net/v/20231130050106540'}
# {'title': "   제로베이스원 박건욱, '안녕' [사진]   ", 'summary': '  [OSEN=지형준 기자] 2일 오후 인천 인스파이어 아레나에서 멜론뮤직어워드(MMA2023) 레드카펫 행사가 열렸다.가수 제로베이스원 박건욱이 포토타임을 하고 있다. 2023.12.02 / jpnews.osen.co.kr  ', 'company': 'OSEN', 'today': ' 2023.12.02 ', 'href': 'http://v.daum.net/v/20231202204852449'}
# {'title': "   [ST포토] 이서, '안녕하세요~ MMA 왔어요'   ", 'summary': "  스포츠투데이 포토 [인천=스포츠투데이 팽현준 기자] 그룹 아이브의 이서가 2일 인천 중구 운서동 인스파이어 아레나에서 열린 '2023 멜론 뮤직 어워드' 레드카펫 행사에 참석하고 있다. 2023.12.02. [스포츠투데이 팽현준 기자 ent@stoo.com]  ", 'company': '스포츠투데이', 'today': ' 2023.12.02 ', 'href': 'http://v.daum.net/v/20231202180610845'}
# {'title': '   희진 "아버지가 아이돌 데뷔 반대..지금은 \'미안하다\'고" 눈물 [안녕자네]   ', 'summary': "  아버지의 반대를 떠올리며 울컥했다. 10일 유튜브 채널 '헤이뉴스'에는 '고3 아들이 좋아하는 아이돌을 만난 아버지(ft. 희진) - 안녕자네 63화'라는 제목의 영상이 게재됐다. 이날 영상에는 그룹 이달의 소녀 출신 아르테미스 멤버 희진이 출연했다. 희진은 평소...  ", 'company': '스타뉴스', 'today': ' 2023.11.11 ', 'href': 'http://v.daum.net/v/20231111004352849'}
# {'title': '   “빅뱅을 이긴 가수” 이지형 ‘뜨거운 안녕’ 열창‥유희열 간접 언급(싱어게인3)   ', 'summary': '  (사진=JTBC ‘싱어게인 시즌3-무명가수전’ 캡처) (사진=JTBC ‘싱어게인 시즌3-무명가수전’ 캡처) [뉴스엔 이하나 기자] ‘뜨거운 안녕’의 이지형이 ‘싱어게인3’에서 아쉽게 탈락했다. 10월 26일 방송된 JTBC ‘싱어게인 시즌3-무명가수전’(이하 ‘싱어게인3...  ', 'company': '뉴스엔', 'today': ' 2023.10.26 ', 'href': 'http://v.daum.net/v/20231026233805984'}
# {'title': '   김기현 "보다 큰 정당"... 이준석 "안녕 얘들아...12월에 결단" [앵커리포트]   ', 'summary': '  어제 김종인 전 비대위원장을 만나 11월 계획을 설명했다면서 12월에 결단하겠다고 했는데요 오늘은 징계 취소 결정이 나자마자, 안녕 얘들아…지지율이나 올리라며 불쾌감을 숨기지 않았는데요 오늘 김 대표와 이 전 대표 목소리 듣고 더정치 시작하겠습니다...  ', 'company': 'YTN', 'today': ' 2023.11.02 ', 'href': 'http://v.daum.net/v/20231102151616507'}
# {'title': '   영화 포스터 이젠 안녕… 합성수지 코팅된 전단지 제한된다   ', 'summary': "  [기자] 최근 한 온라인 커뮤니티에 올라온 사진입니다. 한 영화관에 게시된 공지문인데요. '지난 24일부터 환경부 지침에 따라 영화관 1회용 선전물 배포가 제한됩니다'라고 적혀 있습니다. [앵커] '1회용 선전물'이라고 하면, 영화관 입구 쪽에 놓여 있는 미니...  ", 'company': 'JTBC', 'today': ' 2023.11.28 ', 'href': 'http://v.daum.net/v/20231128103942608'}
# {'title': "   이젠 안녕...메시의 가장 '든든한' 조력자, 코파 아메리카가 마지막 대회   ", 'summary': '  [포포투=한유철] 앙헬 디 마리아가 코파 아메리카 2024를 끝으로 아르헨티나 유니폼을 벗는다. 디 마리아는 아르헨티나의 전설적인 공격수다. 공격 전 지역을 소화할 수 있을 정도로 다재다능하며 그의 왼발은 타의 추종을 불허할 정도다. 패스와 슈팅 등 뛰어난...  ', 'company': '포포투', 'today': ' 2023.11.24 ', 'href': 'http://v.daum.net/v/20231124125504568'}
# {'title': '   [데스크칼럼] 오세훈의 서울시 "안녕하신지…"   ', 'summary': '  자신의 연인도, 딸의 행복도 지켜주지 못했다는 죄책감에 눈물을 보였을 지도 모를 일이다. ‘오세훈의 서울시’는 행복할까, 안녕할까. 서울을 ‘작은 정부’라고 부른다. 대한민국의 중요한 국가시설은 물론 기업, 사람이 서울에 몰려 있기 때문이다. ‘서울시장...  ', 'company': '아이뉴스24', 'today': ' 2023.11.03 ', 'href': 'http://v.daum.net/v/20231103060033066'}
# {'title': '   “안녕 내 사랑, 지미가”...99세 카터, 77년 함께한 아내 마지막 배웅   ', 'summary': '  로잘린 여사 추도식에 참석한 지미 카터 미국 전 대통령. 애틀랜타=로이터연합 "내 사랑, 당신과 떨어져 있을 때마다, 당신이 얼마나 멋진 사람인지를 알게 돼 돌아갈 때마다 감격스러웠어요" 지미 카터(99) 전 미국 대통령이 그의 배우자 로잘린 카터 여사 추도식에...  ', 'company': '세계일보', 'today': ' 2023.11.29 ', 'href': 'http://v.daum.net/v/20231129173237263'}
# {'title': "   보이넥스트도어 명재현-성호, '안녕' [사진]   ", 'summary': '  [OSEN=지형준 기자] 2일 오후 인천 인스파이어 아레나에서 멜론뮤직어워드(MMA2023) 레드카펫 행사가 열렸다. 가수 보이넥스트도어 명재현, 성호가 포토타임을 하고 있다. 2023.12.02 / jpnews.osen.co.kr  ', 'company': 'OSEN', 'today': ' 2023.12.02 ', 'href': 'http://v.daum.net/v/20231202183220205'}
# {'title': "   '청룡영화상', 김혜수와 뜨거운 안녕…최우수작품상은 '밀수' [종합]   ", 'summary': "  청룡영화상이 청룡의 여인 배우 김혜수와의 아름다운 이별을 마무리했다. KBS2 캡처 청룡영화상이 청룡의 여인 배우 김혜수와의 아름다운 이별을 마무리했다. 그가 출연한 '밀수'는 최우수작품상을 차지했다. 24일 제44회 청룡영화상이 여의도 KBS홀에서 개최됐다...  ", 'company': '한국일보', 'today': ' 2023.11.24 ', 'href': 'http://v.daum.net/v/20231124235410148'}
# {'title': "   라이즈 은석 '여러분 안녕~'[엑's HD포토]   ", 'summary': "  (엑스포츠뉴스 영종도, 김한준 기자) 2일 오후 인천 인스파이어 아레나에서 'MMA2023(MELON MUSIC AWARDS, 멜론뮤직어워드)' 레드카펫 행사가 열렸다. 이날 행사에 참석한 라이즈 은석이 포즈를 취하고 있다. 김한준 기자 kowel@xportsnews.com  ", 'company': '엑스포츠뉴스', 'today': ' 2023.12.02 ', 'href': 'http://v.daum.net/v/20231202192803737'}
# {'title': '   "안녕 명태야, 안녕 바다야" 2023 고성통일명태축제 개막   ', 'summary': "  제23회 고성통일명태축제가 지난 26일 개막해 오는 29일까지 4일 동안 거진읍 거진11리 해변 일원에서 열린다. 이번 축제는 '안녕 명태야, 안녕 바다야'라는 주제로 다채로운 체험행사를 마련해 가을바다 정취 만끽할 수 있도록 준비했다. 명태의 본고장이자...  ", 'company': '노컷뉴스', 'today': ' 2023.10.27 ', 'href': 'http://v.daum.net/v/20231027105105268'}
# {'title': '   “추억의 공간, 이제 안녕”…상봉터미널 마지막 발자취 [가봤더니]   ', 'summary': '  30일 오전 마지막 영업을 앞둔 서울 중랑구 상봉터미널을 한 시민이 사진으로 기록하고 있다. 사진=조유정 기자 지난 1985년 문 연 상봉터미널이 30일을 영업을 끝으로 문을 닫는다. 한때 이용객이 하루 평균 2만명을 넘어섰으나 최근 상봉터미널은 인파를 찾아보기...  ', 'company': '쿠키뉴스', 'today': ' 2023.11.30 ', 'href': 'http://v.daum.net/v/20231130115105132'}
# {'title': '   우리 이제는 이별해야 해...다이어와 요리스, 토트넘과 안녕?   ', 'summary': "  [인터풋볼] 김대식 기자 = 토트넘은 이제 팀에 큰 도움이 되지 않는 베테랑들을 정리해야만 한다. 영국 '스카이 스포츠'는 21일(한국시간) 토트넘의 1월 이적시장에 대해서 보도하면서 토트넘이 센터백과 함께 중앙 미드필더와 공격수 영입도 염두해두고 있다고...  ", 'company': '인터풋볼', 'today': ' 2023.11.22 ', 'href': 'http://v.daum.net/v/20231122155747744'}
# {'title': "   '귀저귀 안녕' 은우, 아빠 김준호 교육에 어엿한 형아로 (슈돌)   ", 'summary': '  [동아닷컴] ‘슈퍼맨이 돌아왔다’ 은우가 배변 교육을 시작하며 기저귀와의 이별을 시작한다. 오는 28일 오후 8시 30분에 방송되는 KBS 2TV ‘슈돌’ 503회는 ‘마음껏 자라렴! 아빠가 지켜줄게’ 편으로 소유진과 최강창민의 내레이션으로 꾸며지는 가운데, 김준호...  ', 'company': '스포츠동아', 'today': ' 2023.11.27 ', 'href': 'http://v.daum.net/v/20231127134823271'}
# {'title': "   100년 넘은 엔진룸 안녕…현대차 '유니휠' 기술 공개   ", 'summary': '  【 앵커멘트 】 가솔린 엔진을 단 자동차가 세상에 태어난 지 140년 정도 됐습니다. 겉모습은 세련되게 변했지만, 정작 엔진룸과 실내 그리고 트렁크로 구분된 외관은 변화가 없습니다. 오늘, 현대차가 이 틀을 바꿀 수 있는 기술을 세계 최초로 공개했습니다...  ', 'company': 'MBN', 'today': ' 2023.11.28 ', 'href': 'http://v.daum.net/v/20231128195439428'}
# {'title': "   야구장 응원 풍선, 마트 우산 비닐 '이제 안녕'…계도기간 종료   ", 'summary': '  [세종=뉴시스] 세종시 어진동 정부세종청사 환경부. 2019.09.03. ppkjm@newsis.com [서울=뉴시스] 구무서 기자 = 프로야구 경기장에서의 막대형 비닐 응원봉과 대형마트·백화점 내 빗물 떨어짐을 막기 위한 우산 비닐 등이 사라질 예정이다. 23일 환경부에 따르면...  ', 'company': '뉴시스', 'today': ' 2023.11.23 ', 'href': 'http://v.daum.net/v/20231123053012524'}
# {'title': "   제로베이스원 성한빈 '제로즈 안녕'[엑's HD포토]   ", 'summary': "  (엑스포츠뉴스 영종도, 김한준 기자) 2일 오후 인천 인스파이어 아레나에서 'MMA2023(MELON MUSIC AWARDS, 멜론뮤직어워드)' 레드카펫 행사가 열렸다. 이날 행사에 참석한 제로베이스원 성한빈이 포즈를 취하고 있다. 김한준 기자 kowel@xportsnews.com  ", 'company': '엑스포츠뉴스', 'today': ' 2023.12.02 ', 'href': 'http://v.daum.net/v/20231202202829267'}
# {'title': '   2022년 10월 29일 이후로 바뀐 "안녕"의 의미   ', 'summary': '  앞두고 시민들의 추모메시지가 모이고 있다. ⓒ 1029 이태원참사 시민대책회의 지난해 10.29 이태원 참사 이후 서로에게 묻는 \'안녕\'이란 인사에 조금 더 마음이 담기기 시작했다. "지금까지 우리가 살던 대한민국은, 서울시는 당연한 듯하게 안부를 묻고 \'안녕...  ', 'company': '오마이뉴스', 'today': ' 2023.10.23 ', 'href': 'http://v.daum.net/v/20231023151201805'}
# {'title': "   [SPO 현장]ACL 16강 진출 여부-티켓 확보 고민…잔류 걱정하던 인천 '이젠 안녕'   ", 'summary': "  ▲ '행복 축구'로 올 시즌을 소화 중인 인천 유나이티드. ⓒ한국프로축구연맹 ▲ '행복 축구'로 올 시즌을 소화 중인 인천 유나이티드. ⓒ한국프로축구연맹 ▲ '행복 축구'로 올 시즌을 소화 중인 인천 유나이티드. ⓒ한국프로축구연맹 ▲ '행복 축구'로 올 시즌을...  ", 'company': '스포티비뉴스', 'today': ' 2023.11.25 ', 'href': 'http://v.daum.net/v/20231125074021556'}
# {'title': '   ‘병역 혜택 원천 차단’ 안우진, 결국 군 복무&재활 병행 택했다…2025년 9월까지 ‘잠시만 안녕’ [공식발표]   ', 'summary': '  키움 안우진 / OSEN DB 키움 안우진 / OSEN DB [OSEN=이후광 기자] 키움 히어로즈의 파이어볼러 에이스 안우진(24)이 팔꿈치 재활과 함께 사회복무요원으로 병역 의무를 이행한다. 키움 히어로즈 구단은 28일 "투수 안우진이 12월 18일부터 사회복무요원으로 군 복무...  ', 'company': 'OSEN', 'today': ' 2023.11.28 ', 'href': 'http://v.daum.net/v/20231128132004814'}
# {'title': '   [제주소식]제주항공우주박물관 ‘안녕, 꼬드롱’ 순회전 등   ', 'summary': '  뉴시스] 이정민 기자 = 제주국제자유도시개발센터(이사장 양영철·JDC)가 운영하는 제주항공우주박물관은 국립항공박물관 순회전 ‘안녕, 꼬드롱’을 10일부터 내년 1월 31일까지 1층 기획전시실에서 진행한다고 9일 밝혔다. 이번 전시는 우리나라 최초의 여성...  ', 'company': '뉴시스', 'today': ' 2023.11.09 ', 'href': 'http://v.daum.net/v/20231109134850707'}
# {'title': '   [포토] 장재영 이주형, 안녕하십니까!   ', 'summary': '  1일 그랜드 하얏트 호텔에서 열린 한국프로야구선수협회 총회, 장재영과 이주형이 총회에 참석하고 있다. 허상욱 기자wook@sportschosun.com/2023.12.01/  ', 'company': '스포츠조선', 'today': ' 2023.12.01 ', 'href': 'http://v.daum.net/v/20231201122639138'}
# {'title': "   [442.told] 중요한 순간마다 그가 있었다...'도비' 디 마리아, 코파 끝으로 대표팀과 안녕   ", 'summary': '  [포포투=한유철] 앙헬 디 마리아가 코파 아메리카 2024를 끝으로 아르헨티나 대표팀 은퇴를 발표했다. 디 마리아는 23일(한국시간) 자신의 SNS를 통해 아르헨티나 대표팀 은퇴를 발표했다. 물론 지금 당장은 아니고, 내년 여름에 펼쳐지는 코파 아메리카를 끝으로...  ', 'company': '포포투', 'today': ' 2023.11.24 ', 'href': 'http://v.daum.net/v/20231124195502029'}
# {'title': "   [포토] 라이즈 은석 '안녕, 브리즈'   ", 'summary': '  ‘제18회 W Korea 유방암 인식 향상 캠페인 자선행사’ 포토콜이 24일 오후 서울 중구 포시즌스호텔에서 열렸다. 그룹 라이즈(RIIZE) 은석이 포토타임을 갖고 있다. 더블유코리아는 지난 2006년부터 ‘LOVE YOUR W’ 슬로건을 내걸고 유방암 인식 향상 캠페인을...  ', 'company': 'bnt뉴스', 'today': ' 2023.11.25 ', 'href': 'http://v.daum.net/v/20231125103801246'}
# {'title': '   도쿄돔서 ‘안녕하세요’ ‘BTS’ 외친 콜드플레이…한국 공연 패싱 이유는?[김선영 기자의 오후에 읽는 도쿄]   ', 'summary': '  돔에서 열린 콜드플레이 일본 공연에서 보컬 크리스 마틴이 방탄소년단(BTS)를 언급하고 있다. 도쿄 = 글·사진 김선영 기자 “‘안녕하세요!’ 한국에서 공연 보러온 분들 고마워요. 그리고 내 친구 BTS(방탄소년단)에게 이 노래를 보냅니다” 세계적인 브릿팝 밴드...  ', 'company': '문화일보', 'today': ' 2023.11.08 ', 'href': 'http://v.daum.net/v/20231108130908539'}
# {'title': '   회사에 문제가 있나요? ‘산업보건안전법 41조’, ‘퇴사 사유 정정 신청 제도’ 이것만 알아도 일터가 안녕해질 수 있습니다 [경향시소]   ', 'summary': '  로 시작되는 대자보가 서울의 한 대학에 걸렸던 게 10년 전의 일입니다. 하지만 우리들의 삶도, 일터도 여전히 안녕하지 않습니다. 특히 일터의 안전과 안녕은 수시로 위협받고 있는 것이 사실입니다. 경향신문의 유튜브채널 ‘이런 경향’의 뉴스 해설 콘텐츠...  ', 'company': '경향신문', 'today': ' 2023.11.02 ', 'href': 'http://v.daum.net/v/20231102185435995'}
# {'title': "   원팩트 종우,'안녕' [사진]   ", 'summary': "  [OSEN=지형준 기자] 30일 오후 서울 강남구 청담동 일지아트홀에서 가수 원팩트 첫 번째 미니 앨범 'Moment(모멘트)' 발매 기념 오프라인 미디어 쇼케이스가 열렸다. 원팩트 종우가 포토타임을 하고 있다. 2023.11.30 / jpnews.osen.co.kr  ", 'company': 'OSEN', 'today': ' 2023.11.30 ', 'href': 'http://v.daum.net/v/20231130144920680'}
# {'title': '   \'72년생\' 유재석, \'78년생\' 남궁민에게 \'아유 안녕하십니까\'. "내가 형일 걸 알고 있는데도…"   ', 'summary': '  했다. 이에 유재석은 "저도 얼마 전에 남궁민이 출연하는 \'연인\'에 잠깐 나왔었다. 남궁민이 저쪽에서 오는데 나도 모르게 \'아유 안녕하십니까\'라고 인사했다"며 "내가 형이다. 심지어 내가 형인 걸 알고 있는데도 복장이 그러니까 그렇게 되더라"고 억울해했다...  ', 'company': '스포츠조선', 'today': ' 2023.11.09 ', 'href': 'http://v.daum.net/v/20231109074204778'}
#                                                 title  \
# 0      얼굴 없는 노래방차트 1위 가수 #안녕, 알고보니 '연봉 1억' 받는 대기업 ...
# 1                  "바가지요금 안녕"… 외국인 관광객용 택시 호출 앱 출시
# 2                     “웃으며 춤추듯 운동하니 관절통증도 우울증도 안녕”
# 3      [단독] 우울증에 신음하는 농어촌… 진료받을 정신과가 없어요 [대한민국 정신건...
# 4               여의도순복음교회 신도 5000명, 영화 '안녕하세요' 단체관람
# ..                                                ...
# 95                           [포토] 라이즈 은석 '안녕, 브리즈'
# 96     도쿄돔서 ‘안녕하세요’ ‘BTS’ 외친 콜드플레이…한국 공연 패싱 이유는?[김...
# 97     회사에 문제가 있나요? ‘산업보건안전법 41조’, ‘퇴사 사유 정정 신청 제도...
# 98                                원팩트 종우,'안녕' [사진]
# 99     '72년생' 유재석, '78년생' 남궁민에게 '아유 안녕하십니까'. "내가 형...
#
#                                               summary company         today  \
# 0     기자] 요즘 10대-20대에게 ’얼굴이 없어도‘ 아주 유명한 가수가 있다. 얼굴...    OSEN   2023.11.07
# 1     외국인 관광객 전용 택시 호출 앱 '타바'. 서울시 제공 #최근 서울을 방문한 ...    한국일보         57분전
# 2     1일 경북 구미 새마을운동테마공원 부속동에서 열린 ‘어르신 체육활동’ 참가자들이...    서울신문         2시간전
# 3     인구 대비 정신과 치료를 받은 사람 수가 많은 지역 상위 50곳 중 20곳이 인...    서울신문    9시간전 탐사뉴스
# 4     [서울=뉴시스] 지난 11월29일 서울 영등포구 여의도CGV에서 진행된 영화 '...     뉴시스   2023.12.03
# ..                                                ...     ...           ...
# 95    ‘제18회 W Korea 유방암 인식 향상 캠페인 자선행사’ 포토콜이 24일 오...   bnt뉴스   2023.11.25
# 96    돔에서 열린 콜드플레이 일본 공연에서 보컬 크리스 마틴이 방탄소년단(BTS)를 ...    문화일보   2023.11.08
# 97    로 시작되는 대자보가 서울의 한 대학에 걸렸던 게 10년 전의 일입니다. 하지만...    경향신문   2023.11.02
# 98    [OSEN=지형준 기자] 30일 오후 서울 강남구 청담동 일지아트홀에서 가수 원...    OSEN   2023.11.30
# 99    했다. 이에 유재석은 "저도 얼마 전에 남궁민이 출연하는 '연인'에 잠깐 나왔었...   스포츠조선   2023.11.09
#
#                                      href
# 0   http://v.daum.net/v/20231107093520126
# 1   http://v.daum.net/v/20231204132615538
# 2   http://v.daum.net/v/20231204120201902
# 3   http://v.daum.net/v/20231204050104496
# 4   http://v.daum.net/v/20231203092812554
# ..                                    ...
# 95  http://v.daum.net/v/20231125103801246
# 96  http://v.daum.net/v/20231108130908539
# 97  http://v.daum.net/v/20231102185435995
# 98  http://v.daum.net/v/20231130144920680
# 99  http://v.daum.net/v/20231109074204778
#
# [100 rows x 5 columns]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = f"https://xkcd.com/2672/"

res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')

path = "#comic > a > img"
# 경로 가져오기
tag = soup.select(path)
img_url = 'https:' + tag[0]['src']

# 이진 파일 내용 가져오기
res = requests.get(img_url)

# 파일 입출력 가져오기
#f = open('catoon.jpg','wb')
#f.write(res.content)
#f.close()

# 파일 입출력 가져오기 [안전]
f = open('catoon.jpg','wb')
# 100 바이트씩 읽어서 저장
for chunk in res.iter_content(100):
    f.write(chunk)
f.close()

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = f"https://xkcd.com/2555/"

res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')

path = "#comic > img"
# 경로 가져오기
tag = soup.select(path)
img_url = 'https:' + tag[0]['src']

# 이진 파일 내용 가져오기
res = requests.get(img_url)

# 파일 입출력 가져오기
#f = open('catoon.jpg','wb')
#f.write(res.content)
#f.close()

# 파일 입출력 가져오기 [안전]
f = open('catoon_123.jpg','wb')
# 100 바이트씩 읽어서 저장
for chunk in res.iter_content(100):
    f.write(chunk)
f.close()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# d:\BookExample_Python\Lecture02\Tranning\2023_11_28.ipynb Cell 14 line 1
#      <a href='vscode-notebook-cell:/d%3A/BookExample_Python/Lecture02/Tranning/2023_11_28.ipynb#X20sZmlsZQ%3D%3D?line=10'>11</a> # 경로 가져오기
#      <a href='vscode-notebook-cell:/d%3A/BookExample_Python/Lecture02/Tranning/2023_11_28.ipynb#X20sZmlsZQ%3D%3D?line=11'>12</a> tag = soup.select(path)
# ---> <a href='vscode-notebook-cell:/d%3A/BookExample_Python/Lecture02/Tranning/2023_11_28.ipynb#X20sZmlsZQ%3D%3D?line=12'>13</a> img_url = 'https:' + tag[0]['src']
#      <a href='vscode-notebook-cell:/d%3A/BookExample_Python/Lecture02/Tranning/2023_11_28.ipynb#X20sZmlsZQ%3D%3D?line=14'>15</a> # 이진 파일 내용 가져오기
#      <a href='vscode-notebook-cell:/d%3A/BookExample_Python/Lecture02/Tranning/2023_11_28.ipynb#X20sZmlsZQ%3D%3D?line=15'>16</a> res = requests.get(img_url)
#
# IndexError: list index out of range
