# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(3,3))
# line plot
sns.barplot(data=tips, x='day', y='tip')

# scatter plot
plt.figure(figsize=(5,3))
sns.jointplot(x='total_bill', y='tip', data=tips)

plt.figure(figsize=(5,3))
sns.jointplot(x='size', y='tip', data=tips)

# %%
# histogram 분포

plt.figure(figsize=(5,5))
sns.distplot(tips['tip'], bins=30)
plt.show()

# box plot
sns.boxplot(data=tips, x='day', y='tip')
sns.boxplot(data=tips, x='day', y='tip', hue='smoker')
sns.boxplot(data=tips, x='day', y='tip', hue='sex')
# Out:
# C:\Users\GJ\AppData\Local\Temp\ipykernel_13072\3595919926.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['tip'], bins=30)
# <Axes: xlabel='day', ylabel='tip'>

# %%
# regression plot (회귀 직석)
sns.regplot(x='total_bill', y='tip', data=tips)

# countplot()
sns.countplot(x=tips.sex, data=tips)
plt.show()

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# 남성과 여성의 수를 bar chart로 표현하시오...

sns.countplot(x=titanic.sex, data=titanic)
plt.show()

sns.countplot(x=titanic.who, data=titanic)
plt.show()

sns.countplot(x=titanic.who, data=titanic, hue='pclass')
plt.show()

# %%
# 승객의 연령분포
sns.distplot(titanic.age, bins=50)
plt.show()
# Out:
# C:\Users\GJ\AppData\Local\Temp\ipykernel_13072\2241831256.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic.age, bins=50)

# %%
# 생존자와 사망수의 그래프...

sns.countplot(x=titanic.survived, data=titanic)

sns.countplot(x=titanic.survived, data=titanic, hue='sex')

sns.countplot(x=titanic.survived, data=titanic, hue='pclass')
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
# 연령과 생존률의 회귀직선...

#sns.regplot(x='age', y='survived',data=titanic)
sns.lmplot(x='age', y='survived', data=titanic, hue='sex')
# Out:
# c:\Users\GJ\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
