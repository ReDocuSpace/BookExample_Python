# %%
import pandas as pd

infect_dust_dict = {}

infect_dust_dict = pd.read_csv('CSV\한국환경공단_도로 재비산먼지 측정 정보_20170331_cng.csv',encoding='euckr')
# Out:
#          측정일자      측정시간  지역  지역명     도로명            시작점           종점  기온(℃)  \
# 0  2017-03-07  10:47:00  서울  강서구    개화동로    방화동 621-24대     개화동 659천     10
# 1  2017-03-07  11:14:00  서울  강서구    공항대로     염창동 286-4제  공항동 434-10잡      5
# 2  2017-03-07  11:41:00  서울  강서구     양천로       염창동 260대  방화동 516-2 차      1
# 3  2017-03-07  11:52:00  서울  강서구     초원로  방화동 247-284 대   방화동 651-9학      1
# 4  2017-03-07  11:55:00  서울  강서구  마곡중앙5로        방화대로300     마곡중앙로145      1
#
#    습도(%)  재비산먼지평균농도(㎍/㎥)  오염범례
# 0     42              19  매우좋음
# 1     39              30  매우좋음
# 2     39              22  매우좋음
# 3     39              27  매우좋음
# 4     39               9  매우좋음
